# %%
print("Hello World")
print("*"*10)
print(2 + 2)

# Function

def func():
    
    print("Inner Function!")
    
    def x():
        print("Nested Function!")
            
    print(x())   
       
      
func()        

# A function which returns a value.It has an optional parameter y

def required_optional(x, y=10):
    return x + y


optional = required_optional(2)
optional_ignored = required_optional(2,2)
print(optional)
print(optional_ignored)
# Out:
# Hello World
# **********
# 4
# Inner Function!
# Nested Function!
# None
# 12
# 4

# %%
# Scope: global

x = 1
y = 2
z = 3

def func1():
    print(x)
    print(y)
    print(z)
   

func1() # Calling the function






# Scope: local

def func2():
    m = 1
    n = 2
    p = 3

    print (" Values of the local variables ( m , n , and p respectively) within the scope of func2(): ", m,n,p) 


func2()    

# NameError: name 'm' is not defined. As m,n,p is defined in local scope of the function func2()   
#print (m)
#print (n)
#print (p)
# Out:
# 1
# 2
# 3
#  Values of the local variables ( m , n , and p respectively) within the scope of func2():  1 2 3

# %%
def f ():
    m = 1
    n = 2
    p = 3
    print (m)
    print (n)
    print (p)
 

f()

# Declaing global variable inside a function: Bad practice !!!

x = 100

def g():
    global x
    x += 1
    print(x)
   
print("Initial value of x : ", x)

print("The value of x after calling the function g() :")
g()
# Out:
# 1
# 2
# 3
# Initial value of x :  100
# The value of x after calling the function g() :
# 101

# %%
age = input("How old are you?")
age = int(age)

if age < 21:
    print("You are young!")
else:
    print("Wow, you are old enough!")   

# Exception Handling: 
a = input("type a number")
b = input("type another number")
c = int(a)
d = int(b)

try:
    print(c / d)
except ZeroDivisionError:
    print("b cannot be zero. Try again!")

# %%
# Creating Object from Class:

class Class :
    print ( "Mafuz created an object using the class Class!" )

    
newobject = Class()

print (type(newobject))
print (newobject)

# Defining a Class with print_orange method

class Orange:
    print ("Orange created!")
    def print_orange(self):
        print (self)

        
Orange().print_orange()

# Defining a Mango class and creating a mango object from the Mango class 

class Mango :
    
    print ("Orange created!")
    
    def __init__ ( self ):
        self .color = "mango"
        self .weight = 10
        
    def print_mango (self):
        print (self)
        print (self.color)
        print (self.weight)
        
        
mango = Mango()
mango.print_mango()

# %%
class Orange :
    def __init__ ( self , weight , color ):
        """all weights are in oz"""
        self .weight = weight
        self .color = color
        
        
orange = Orange( 10 , 'Orange' , )
print(orange.weight)
print(orange.color)

# %%
class Orange ():
    def __init__ ( self ):
        """all weights are in oz"""
        self .weight = 6
        self .color = 'orange'
        self .mold = 0
        
    def rot ( self , days , temperature):
        self .mold = days * (temperature * .1 )
        
        
orange = Orange()
print (orange.mold)

orange.rot( 10 , 98 )
print (orange.mold)

# %%
# Creating a Parent Class

class Parent ():
    
    def __init__ ( self , name , height , weight , eye_color ):
        """height is in feet, weight in lbs."""
        self .name = name
        self .height = height
        self .weight = weight
        self .eye_color = eye_color
        
    def print_name ( self ):
        print ( self.name)
        
        
tom = Parent( "Tom" , 6 , 150 , "Brown" )
print (tom.name)
print (tom.height)
print (tom.weight)
print (tom.eye_color)
tom.print_name()

# %%
# Inheritance in action. Creating a Parent and a Child class.
# The Child Class inherits methods and attributes from it's Parent Class.

class Parent ():
    
    def __init__ ( self , name , height , weight , eye_color):
        # height is in feet, weight in lbs.
        self.name = name
        self.height = height
        self.weight = weight
        self.eye_color = eye_color
        
    def print_name ( self ):
        print ( self.name)
        
class Child (Parent):
    
    def print_cartoon ( self , favorite_cartoon):
        print ("{}'s favorite cartoon is {}" .format(self.name, favorite_cartoon))
        

        
child = Child( "Lauren" , 4 , 45 , "Blue" )
print (child.name)
print (child.height)
print (child.weight)
print (child.eye_color)
child.print_name()
child.print_cartoon( 'DuckTales' )

# %%
# Polymorphism: the ability (in programming) to present the same interface for differing underlying forms (data types)

print( 'Hello World' )
print( 200 )
print( 200.1 )


# Abstraction: 
"""
When we design object-oriented programs, we create abstractions of different concepts
that all work together to form our program. Abstraction allows us to model objects with
clear boundaries, and have them interact with each other.
"""

# Encapsulation: In object-oriented programming, encapsulation hides our codes internal data.
# The method has a variable called data . When we call get_data , there is no way for us to
# access this variable because of encapsulation. 

class Data :
    def get_data (self, n):
        data = [ 1 , 3 , 5 , 7 , 9 ]
        data.append(n)

# Composition:
# Our dog Stanley has an owner — a Person object named Mick Jagger — we can easily reference

class Dog ():
    def __init__ ( self , name , breed , owner):
        self .name = name
        self .breed = breed
        self .owner = owner
        
class Person ():
    def __init__ ( self , name):
        self .name = name
        
        
mick = Person( "Mick Jagger" )
dog = Dog( "Stanley" , "French Bulldog" , mick)
print (dog.owner.name)

# %%
# How the variables work ??? Primitive and Reference Types:


# number points to an integer object with the value 100
number = 100
# When we assign a new value to number, it points to a new integer object with the value 101
number = 101
print(f"The 'number' variable is assigned to {number}.")
x = 10
y = x
x += 1
"""x points to an integer object with a value of 10, and when we create
y , it points to the same integer object. When we increment x , x points to a new integer object
—with a value of 11, but the integer object with a value of 10 is not discarded, because it is
being used: y still points to the integer object with a value of 10 ."""
print(f"The value of the variable 'x' is {x}")
print(f"The value of the variable 'y' is {y}")


# Observe the change in output
list_1 = [1, 2, 3]
list_2 = list_1
list_1[2] = 100
print(list_1)
print(list_2)
"""The output will be [1, 2, 100] twice. The reason is that both x and y point to the same list
object. In the third line, we make a change to that single list object, and when we print both
variables, it prints the list object they both point to."""

# %%
# The 'is' keyword 

class Person :
    def __init__ ( self ):
        self .name = 'Bob'
        
bob = Person()
the_same_bob = bob
print (bob is the_same_bob)

another_bob = Person()
print (bob is another_bob)

"""
When we use the keyword 'is' with bob and the_same_bob , the result is True because both
variables point to the same Person object. When we create a new Person object and compare
it to the original bob the result is False because the variables point to different Person
objects.
"""

# %%
# None:

x = 10
if x:
    print ("x is not None")
else :
    print ("x is None :( ")

y = None

if y:
    print ("y is not None")
else :
    print ("y is None:(")

# %%
# Classes Are Objects
# Python turns it into an object — which you can then use in your program

class Test :
    pass


print (Test)

# %%
# Instance Variable of the class Fruit 

class Fruit:
    def __init__(self, name):
        self.name = name
        
        
fruit = Fruit( "Mango" )
print (fruit.name)



# Class variable of the class Person

class Person:
    interests = ["swimming" , "eating" , "sleeping"]
    def __init__(self, name):
        self.name = name
        
        
print (Person.interests)



# Implementation of class variable

class Liger:
    interests = ["swimming" , "eating" , "sleeping"]
    def __init__(self, name):
        self.name = name

        
larry = Liger("Larry")
print (larry.interests)

# %%
# Private variables

"""Unlike other languages Python does not have private variables. Variables that are not
private are called public variables, and all of Python’s variables are public."""

class PublicPrivateExample:
    
    def __init__ ( self ):
        self .public_variable = "callers know they can access this"
        self ._dontusethisvariable = "callers know they shouldn't access this"
        
    def public_method( self ):
        # callers know they can use this method
        pass
    
    def _dont_use_this_method( self ):
        # callers know they shouldn't use this method
        pass

# %%
# Overriding Methods

class Mammal :
    
    def __init__(self , name):
        self.hunger = 100
        self.tired = 100
        self.name = name
        
    def print_result(self , amount , action):
        print ("{} {} decreased by {}.".format( self .name , action , amount))
        
    def eat(self , decrease):
        self.hunger -= decrease
        self.print_result(decrease , 'hunger')
        
    def sleep(self , decrease):
        self.tired -= decrease
        self.print_result(decrease , 'tiredness')
        
class Dolphin(Mammal):
    pass

class Tiger(Mammal):
    def sleep(self , decrease):
        self.tired -= decrease
        print("The tiger is really tired!")

        
dolphin = Dolphin('dolphin')
dolphin.eat(10)
dolphin.sleep(10)

tiger = Tiger('tiger')
tiger.eat(10)
tiger.sleep(10)

"""We created two classes that inherit from Mammal. The first class, Dolphin , inherits all of its
functionality from the Mammal parent class without making any changes. The second class
Tiger defines a method called sleep , with different functionality than the sleep method it
inherited from its parent class. When we call tiger.sleep , the new method we defined gets
called instead of the inherited method."""

# %%
# Super function
# The built-in super function, lets us call a method a class inherited from its parent

class Tiger (Mammal):
    def sleep(self, decrease):
        super().sleep(decrease)
        print ("The tiger is really tired!")
        
        
tiger = Tiger('tiger')
tiger.eat(10)
tiger.sleep(10)

# %%
# Overriding Built-in Methods

class Lion :
    
    def __init__(self, name):
        self .name = name
        
        
lion = Lion("Dilbert")
print (lion)

class Genius:
    
    def __init__ (self, name):
        self.name = name
        
    def __repr__(self):
        return self.name
    
    
genius = Genius("Dilbert")
print (genius)

"""When we print our Lion object, Python calls the __repr__ method on our object, which it
inherited from the Object parent class. It prints whatever the __repr__ method returns. We
can override this built-in method to change what happens when the print function prints our
object.Because we overrode the __repr__ method, when we print our Genius object, the Genius object’s
name— Dilbert — gets printed instead of something like <__main__.Genius object at 0x101178828 >
which the inherited __repr__ method would have returned."""

# %%
# Plotting a Simple Line Graph

import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]

plt.style.use('seaborn-darkgrid')  # type: ignore

fig, ax = plt.subplots()

ax.plot(squares, linewidth=3)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()

# %%
# Correcting the Plot

import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3) # notice the change in definition

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()

# %%
plt.style.availabl  # type: ignoree

# %%
# Plotting and Styling Individual Points with scatter()

plt.style.use('seaborn-darkgrid')
fig, ax = plt.subplots()
ax.scatter(2, 4)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots()
ax.scatter(2, 4, s=200)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(axis='both', which='major', labelsize=14)

# %%
# Plotting a Series of Points with scatter()

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn')

fig, ax = plt.subplots()

ax.scatter(x_values, y_values, s=100)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(axis='both', which='major', labelsize=14)

# %%
# Calculating Data Automatically

x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots()

# Defining Custom Colors

#ax.scatter(x_values, y_values, c=(0, 0.8, 0), s=10)
#ax.scatter(x_values, y_values, c='red', s=10)
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set the range for each axis.
ax.axis([0, 1100, 0, 1100000])
plt.show()

# %%
# Saving Our Plots Automatically
# plt.savefig('squares_plot.png', bbox_inches='tight')
