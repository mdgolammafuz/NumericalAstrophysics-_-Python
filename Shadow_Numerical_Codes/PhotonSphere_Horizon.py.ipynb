# %%
print("Hi! Try me! I dare!")
# Out:
# Hi! Try me! I dare!

# %%
from sympy import *
q,s,t,r = symbols("q,s,t,r")
g_tt = 1 + (2/r) + (q/r**2) + (s/r**3) + (t/r**4)
Horizon_Equation = g_tt.subs({q:1,s:1,t:1})
horizons = solve(Horizon_Equation,dict=True)
for horizon in horizons:
   print(horizon)
# Out:
# {r: -1}
# {r: -1/3 - 1/(3*(-1/2 - sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)/3}
# {r: -1/3 - (-1/2 + sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)/3 - 1/(3*(-1/2 + sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3))}
# {r: -(3*sqrt(93)/2 + 29/2)**(1/3)/3 - 1/3 - 1/(3*(3*sqrt(93)/2 + 29/2)**(1/3))}

# %%
# Expression for Delta in terms of a,b,c:
a,b,c = symbols("a,b,c")
Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)
Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c)

# %%
z=symbols("z")

# Horizon equation
z1 = z**4 + (2*q-3)*(z**2) +(q+s-1)*z + (q/4) + (s/2) + t - (3/16)

#Photon Sphere Equation
z2 = z**4 + (16*q-27)*(z**2) + (24*q + 20*s -27)*z + 9*q + 15*s + 3*t- (243/256)

# %%
x = Symbol('x')
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')

# %%
expr = a*x*x + b*x + c
solve(expr, x)
# Out:
# [(-b - sqrt(-4*a*c + b**2))/(2*a), (-b + sqrt(-4*a*c + b**2))/(2*a)]

# %%
from sympy import Symbol, solve, pprint
s = Symbol('s')
u = Symbol('u')
t = Symbol('t')
a = Symbol('a')
expr = u*t + (1/2)*a*t*t - s
t_expr = solve(expr,t)
t_expr
# Out:
# [(-u - 1.4142135623731*sqrt(a*s + 0.5*u**2))/a,
#  (-u + 1.4142135623731*sqrt(a*s + 0.5*u**2))/a]

# %%
from sympy import*
r,Q,R,T=symbols('r,Q,R,T')
First_Energy_Condition = Q*(r**2) + 2*r*R + 3*T

First_Energy_Condition = solve(First_Energy_Condition,r)
First_Energy_Condition
# Out:
# [(-R - sqrt(-3*Q*T + R**2))/Q, (-R + sqrt(-3*Q*T + R**2))/Q]

# %%
# Third_Energy_Condition = 2*Q*r**2 + 5*r*R + 9*T

# Roots_Third_Energy_Condition = solveset (Eq(Third_Energy_Condition,0),r)

# simplify(Roots_Third_Energy_Condition)

# %%
#######Horizon = x**4 - 2*x**3 + q*x**2 + s*x + t 

#Horizon_Substituted = expand(Horizon.subs(x,z1+(1/2))) 

#collect(Horizon_Substituted, z1)

# %%
from sympy import*
y=Symbol("y")
Photon_Sphere = 2*y**4 - 6*y**3 + 4*q*y**2 + 5*s*y + 6*t 

Photon_Sphere_Substituted = expand(Photon_Sphere.subs(y,z2+(3/4)) )

collect(Photon_Sphere_Substituted, z2)
# Out:
#       4  8          4  7          4  6          4  5           4  4
# 32.0⋅q ⋅z  + 192.0⋅q ⋅z  + 504.0⋅q ⋅z  + 756.0⋅q ⋅z  + 708.75⋅q ⋅z  + 425.25⋅q
#
# 4  3              4  2              4                    4          3    7
#  ⋅z  + 159.46875⋅q ⋅z  + 34.171875⋅q ⋅z + 3.20361328125⋅q  + 160.0⋅q ⋅s⋅z  + 8
#
#       3    6           3    5           3    4             3    3
# 40.0⋅q ⋅s⋅z  + 1890.0⋅q ⋅s⋅z  + 2362.5⋅q ⋅s⋅z  + 1771.875⋅q ⋅s⋅z  + 797.34375⋅
#
#  3    2                3                     3            3    6          3
# q ⋅s⋅z  + 199.3359375⋅q ⋅s⋅z + 21.357421875⋅q ⋅s + 192.0⋅q ⋅t⋅z  + 864.0⋅q ⋅t⋅
#
#  5           3    4           3    3           3    2            3
# z  + 1620.0⋅q ⋅t⋅z  + 1620.0⋅q ⋅t⋅z  + 911.25⋅q ⋅t⋅z  + 273.375⋅q ⋅t⋅z + 34.17
#
#       3           3  10          3  9          3  8          3  7           3
# 1875⋅q ⋅t + 64.0⋅q ⋅z   + 288.0⋅q ⋅z  + 324.0⋅q ⋅z  - 648.0⋅q ⋅z  - 2551.5⋅q ⋅
#
#  6            3  5               3  4               3  3                   3
# z  - 3827.25⋅q ⋅z  - 3332.84375⋅q ⋅z  - 1797.28125⋅q ⋅z  - 580.3154296875⋅q ⋅z
#
# 2                   3                       3          2  2  6           2  2
#   - 97.94091796875⋅q ⋅z - 5.74969482421875⋅q  + 300.0⋅q ⋅s ⋅z  + 1350.0⋅q ⋅s ⋅
#
#  5            2  2  4            2  2  3                2  2  2
# z  + 2531.25⋅q ⋅s ⋅z  + 2531.25⋅q ⋅s ⋅z  + 1423.828125⋅q ⋅s ⋅z  + 427.1484375⋅
#
#  2  2                    2  2          2      5           2      4           2
# q ⋅s ⋅z + 53.3935546875⋅q ⋅s  + 720.0⋅q ⋅s⋅t⋅z  + 2700.0⋅q ⋅s⋅t⋅z  + 4050.0⋅q
#
#       3           2      2              2                     2              2
# ⋅s⋅t⋅z  + 3037.5⋅q ⋅s⋅t⋅z  + 1139.0625⋅q ⋅s⋅t⋅z + 170.859375⋅q ⋅s⋅t + 240.0⋅q
#
#     9          2    8          2    7           2    6             2    5
# ⋅s⋅z  + 900.0⋅q ⋅s⋅z  + 540.0⋅q ⋅s⋅z  - 2835.0⋅q ⋅s⋅z  - 7441.875⋅q ⋅s⋅z  - 87
#
#           2    4                2    3                  2    2
# 70.78125⋅q ⋅s⋅z  - 5940.078125⋅q ⋅s⋅z  - 2344.74609375⋅q ⋅s⋅z  - 485.123291015
#
#      2                         2            2  2  4         2  2  3
# 625⋅q ⋅s⋅z - 37.1859741210938⋅q ⋅s + 432.0⋅q ⋅t ⋅z  + 1296⋅q ⋅t ⋅z  + 1458.0⋅q
#
# 2  2  2          2  2               2  2          2    8        2    7
#  ⋅t ⋅z  + 729.0⋅q ⋅t ⋅z + 136.6875⋅q ⋅t  + 288.0⋅q ⋅t⋅z  + 864⋅q ⋅t⋅z  + 1.136
#
#                  2    6           2    5            2    4             2    3
# 86837721616e-13⋅q ⋅t⋅z  - 3402.0⋅q ⋅t⋅z  - 6378.75⋅q ⋅t⋅z  - 5740.875⋅q ⋅t⋅z
#
#              2    2                2                       2           2  12
# - 2822.4375⋅q ⋅t⋅z  - 696.8671875⋅q ⋅t⋅z - 59.49755859375⋅q ⋅t + 48.0⋅q ⋅z   +
#
#       2  11          2  10           2  9              2  8            2  7
#  144⋅q ⋅z   - 162.0⋅q ⋅z   - 1215.0⋅q ⋅z  - 1594.6875⋅q ⋅z  + 820.125⋅q ⋅z  +
#
#              2  6                 2  5                     2  4
# 5039.265625⋅q ⋅z  + 7251.3515625⋅q ⋅z  + 5766.58520507813⋅q ⋅z  + 2739.3332519
#
#       2  3                     2  2                     2
# 5313⋅q ⋅z  + 729.567352294922⋅q ⋅z  + 89.5733184814453⋅q ⋅z + 3.34824657440186
#
#   2            3  5            3  4              3  3                3  2
# ⋅q  + 250.0⋅q⋅s ⋅z  + 937.5⋅q⋅s ⋅z  + 1406.25⋅q⋅s ⋅z  + 1054.6875⋅q⋅s ⋅z  + 39
#
#              3                     3            2    4             2    3
# 5.5078125⋅q⋅s ⋅z + 59.326171875⋅q⋅s  + 900.0⋅q⋅s ⋅t⋅z  + 2700.0⋅q⋅s ⋅t⋅z  + 30
#
#         2    2              2                     2              2  8
# 37.5⋅q⋅s ⋅t⋅z  + 1518.75⋅q⋅s ⋅t⋅z + 284.765625⋅q⋅s ⋅t + 300.0⋅q⋅s ⋅z  + 900.0⋅
#
#    2  7              2  5                 2  4                  2  3
# q⋅s ⋅z  - 3543.75⋅q⋅s ⋅z  - 6644.53125⋅q⋅s ⋅z  - 5980.078125⋅q⋅s ⋅z  - 2965.03
#
#          2  2                     2                         2               2
# 90625⋅q⋅s ⋅z  - 763.4033203125⋅q⋅s ⋅z - 76.0391235351563⋅q⋅s  + 1080.0⋅q⋅s⋅t ⋅
#
#  3               2  2               2                  2                7
# z  + 2430.0⋅q⋅s⋅t ⋅z  + 1822.5⋅q⋅s⋅t ⋅z + 455.625⋅q⋅s⋅t  + 720.0⋅q⋅s⋅t⋅z  + 16
#
#             6                 5                  4                     3
# 20.0⋅q⋅s⋅t⋅z  - 1215.0⋅q⋅s⋅t⋅z  - 7593.75⋅q⋅s⋅t⋅z  - 10251.5625⋅q⋅s⋅t⋅z  - 666
#
#                 2
# 3.515625⋅q⋅s⋅t⋅z  - 2118.45703125⋅q⋅s⋅t⋅z - 243.3251953125⋅q⋅s⋅t + 120.0⋅q⋅s⋅z
#
# 11              10              9                 8                  7
#    + 270.0⋅q⋅s⋅z   - 607.5⋅q⋅s⋅z  - 2581.875⋅q⋅s⋅z  - 2050.3125⋅q⋅s⋅z  + 3588.
#
#             6                      5                         4
# 046875⋅q⋅s⋅z  + 9887.12890625⋅q⋅s⋅z  + 10683.0322265625⋅q⋅s⋅z  + 6460.43884277
#
#          3                         2
# 344⋅q⋅s⋅z  + 2181.75399780273⋅q⋅s⋅z  + 353.306007385254⋅q⋅s⋅z + 19.77410316467
#
#                 3  2          3              3          2  6          2  5
# 29⋅q⋅s + 432⋅q⋅t ⋅z  + 648⋅q⋅t ⋅z + 243.0⋅q⋅t  + 432⋅q⋅t ⋅z  + 648⋅q⋅t ⋅z  - 1
#
#          2  4             2  3                2  2                 2
# 215.0⋅q⋅t ⋅z  - 3645.0⋅q⋅t ⋅z  - 3417.1875⋅q⋅t ⋅z  - 1435.21875⋅q⋅t ⋅z - 194.6
#
#            2            10            9              8               7
# 6015625⋅q⋅t  + 144⋅q⋅t⋅z   + 216⋅q⋅t⋅z  - 891.0⋅q⋅t⋅z  - 2430.0⋅q⋅t⋅z  - 637.8
#
#         6                  5                     4                     3
# 75⋅q⋅t⋅z  + 4784.0625⋅q⋅t⋅z  + 8276.5078125⋅q⋅t⋅z  + 6612.2578125⋅q⋅t⋅z  + 279
#
#                    2                                                         1
# 3.33325195313⋅q⋅t⋅z  + 511.104858398438⋅q⋅t⋅z + 22.6385650634766⋅q⋅t + 16⋅q⋅z
#
# 4         13            12            11               10                 9
#   + 24⋅q⋅z   - 153.0⋅q⋅z   - 405.0⋅q⋅z   + 167.0625⋅q⋅z   + 1754.15625⋅q⋅z  +
#
#                  8                  7                       6
# 2165.37109375⋅q⋅z  - 563.8359375⋅q⋅z  - 4547.06762695313⋅q⋅z  - 6067.066772460
#
#       5                       4                       3
# 94⋅q⋅z  - 4330.21293640137⋅q⋅z  - 1754.30085754395⋅q⋅z  - 355.649868965149⋅q⋅z
#
# 2                                                        4  4            4  3
#   - 27.8013024330139⋅q⋅z - 0.716091334819794⋅q + 78.125⋅s ⋅z  + 234.375⋅s ⋅z
#
#               4  2                4                     4          3    3
# + 263.671875⋅s ⋅z  + 131.8359375⋅s ⋅z + 24.71923828125⋅s  + 375.0⋅s ⋅t⋅z  + 84
#
#       3    2             3                   3            3  7           3  6
# 3.75⋅s ⋅t⋅z  + 632.8125⋅s ⋅t⋅z + 158.203125⋅s ⋅t + 125.0⋅s ⋅z  + 281.25⋅s ⋅z
#
#             3  5                3  4                  3  3
# - 210.9375⋅s ⋅z  - 1318.359375⋅s ⋅z  - 1779.78515625⋅s ⋅z  - 1156.8603515625⋅s
#
# 3  2                     3                       3          2  2  2
#  ⋅z  - 378.204345703125⋅s ⋅z - 50.0564575195313⋅s  + 675.0⋅s ⋅t ⋅z  + 1012.5⋅s
#
# 2  2               2  2          2    6          2    5             2    4
#  ⋅t ⋅z + 379.6875⋅s ⋅t  + 450.0⋅s ⋅t⋅z  + 675.0⋅s ⋅t⋅z  - 1265.625⋅s ⋅t⋅z  - 3
#
#          2    3                 2    2                  2
# 796.875⋅s ⋅t⋅z  - 3559.5703125⋅s ⋅t⋅z  - 1495.01953125⋅s ⋅t⋅z - 240.2709960937
#
#    2           2  10          2  9             2  8             2  7
# 5⋅s ⋅t + 75.0⋅s ⋅z   + 112.5⋅s ⋅z  - 464.0625⋅s ⋅z  - 1265.625⋅s ⋅z  - 332.226
#
#       2  6                  2  5                     2  4
# 5625⋅s ⋅z  + 2491.69921875⋅s ⋅z  + 4298.18115234375⋅s ⋅z  + 3443.88427734375⋅s
#
# 2  3                     2  2                    2                      2
#  ⋅z  + 1497.04856872559⋅s ⋅z  + 320.88794708252⋅s ⋅z + 23.656153678894⋅s  + 54
#
#        3              3            2  5            2  4             2  3
# 0.0⋅s⋅t ⋅z + 405.0⋅s⋅t  + 540.0⋅s⋅t ⋅z  + 405.0⋅s⋅t ⋅z  - 1822.5⋅s⋅t ⋅z  - 318
#
#          2  2                  2                     2              9
# 9.375⋅s⋅t ⋅z  - 1879.453125⋅s⋅t ⋅z - 384.43359375⋅s⋅t  + 180.0⋅s⋅t⋅z  + 135.0⋅
#
#      8               7                6                  5
# s⋅t⋅z  - 1215.0⋅s⋅t⋅z  - 2126.25⋅s⋅t⋅z  + 797.34375⋅s⋅t⋅z  + 5382.0703125⋅s⋅t⋅
#
#  4                      3                        2
# z  + 6279.08203125⋅s⋅t⋅z  + 3556.0107421875⋅s⋅t⋅z  + 925.908508300781⋅s⋅t⋅z +
#
#                                13           12            11              10
# 60.6996917724609⋅s⋅t + 20.0⋅s⋅z   + 15.0⋅s⋅z   - 202.5⋅s⋅z   - 354.375⋅s⋅z   +
#
#                9                    8                    7
#  474.609375⋅s⋅z  + 1836.73828125⋅s⋅z  + 1324.16015625⋅s⋅z  - 1697.9150390625⋅s
#
#   6                       5                       4                      3
# ⋅z  - 4376.64825439453⋅s⋅z  - 4262.59727478027⋅s⋅z  - 2267.0291519165⋅s⋅z  - 6
#
#                    2                                                    4
# 23.385457992554⋅s⋅z  - 70.2312505245209⋅s⋅z - 2.45416671037674⋅s + 162⋅t  + 21
#
#    3  4          3  2          3                3        2  8          2  6
# 6⋅t ⋅z  - 729.0⋅t ⋅z  - 729.0⋅t ⋅z - 205.03125⋅t  + 108⋅t ⋅z  - 729.0⋅t ⋅z  -
#
#        2  5               2  4             2  3                  2  2
# 729.0⋅t ⋅z  + 1025.15625⋅t ⋅z  + 2460.375⋅t ⋅z  + 1922.16796875⋅t ⋅z  + 691.98
#
#         2                       2         12            10            9
# 046875⋅t ⋅z + 36.5597534179688⋅t  + 24⋅t⋅z   - 243.0⋅t⋅z   - 243.0⋅t⋅z  + 751.
#
#          8              7                  6                   5
# 78125⋅t⋅z  + 1640.25⋅t⋅z  + 358.8046875⋅t⋅z  - 2306.6015625⋅t⋅z  - 3522.026733
#
#          4                      3                      2
# 39844⋅t⋅z  - 2479.5966796875⋅t⋅z  - 860.73747253418⋅t⋅z  - 82.2594451904297⋅t⋅
#
#                             16         14         13              12
# z + 3.66708326339722⋅t + 2⋅z   - 27.0⋅z   - 27.0⋅z   + 129.09375⋅z   + 273.375
#
#   11                10                 9                     8
# ⋅z   - 93.97265625⋅z   - 845.75390625⋅z  - 918.578430175781⋅z  + 211.438476562
#
#    7                     6                     5                     4
# 5⋅z  + 1561.97282409668⋅z  + 1886.33866882324⋅z  + 1180.77375555038⋅z  + 384.4
#
#             3                     2
# 7113609314⋅z  + 48.8954692482948⋅z  + 2.62453132867813⋅z + 0.0505899866111577

# %%
eq1 = x**2*(q-(3/2)) + x*(q+s-1) + (s*(1/2) + q*(1/4) + t - (3/16))

eq2 = Photon_Sphere_Substituted.subs(z2,0)

#result = solve([],[])

#eq2

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sympy import*
init_printing(use_unicode=True)
import fractions
import math

# %%
from sympy import symbols,Symbol,solve
q,s,t,r = symbols("q,s,t,r")
g_tt = 1 + (2/r) + (q/r**2) + (s/r**3) + (t/r**4)
Horizon_Equation = g_tt.subs({q:3/2,s:1/2,t:9/16})
horizons = solve(Horizon_Equation)
h1 = []
for horizon in horizons:
    hr = horizon
    if hr.is_positive and hr.is_real:
        print(hr)
        h1.append(hr)
        
if len(h1)>0:       
    z = max(h1)
    print(z)

# %%
z=symbols("z")

# Horizon equation
z1 = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))

#Photon Sphere Equation
z2 = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))

# %%
z1
# Out:
# q   s        4    2
# ─ + ─ + t + z  + z ⋅(q - 1.5) + z⋅(q + s - 1) - 0.1875
# 4   2

# %%
z2
# Out:
#                            4    2
# 1.125⋅q + 1.875⋅s + 3⋅t + z  + z ⋅(2⋅q - 3.375) + z⋅(3⋅q + 2.5⋅s - 3.375) - 0.
#
#
# 94921875

# %%
from sympy import*
Q,R,T,r = symbols("Q,R,T,R")
First_Energy_Condition = Q*(r**2) + 2*r*R + 3*T

Roots_First_Energy_Condition = solve (First_Energy_Condition,r)

Roots_First_Energy_Condition
# Out:
# ⎡        _______         _______⎤
# ⎢       ╱  -T           ╱  -T   ⎥
# ⎢-√3⋅  ╱  ───── , √3⋅  ╱  ───── ⎥
# ⎣    ╲╱   Q + 2      ╲╱   Q + 2 ⎦

# %%
Third_Energy_Condition = 2*Q*r**2 + 5*r*R + 9*T

Roots_Third_Energy_Condition = solveset (Eq(Third_Energy_Condition,0),r)

Roots_Third_Energy_Condition
# Out:
# ⎧       _________        _________⎫
# ⎪      ╱   -T           ╱   -T    ⎪
# ⎨-3⋅  ╱  ─────── , 3⋅  ╱  ─────── ⎬
# ⎪   ╲╱   2⋅Q + 5     ╲╱   2⋅Q + 5 ⎪
# ⎩                                 ⎭

# %%
Horizon = x**4 - 2*x**3 + q*x**2 + s*x + t 

Horizon_Substituted = expand(Horizon.subs(x,z1+(1/2))) 

collect(Horizon_Substituted,z1)
# Out:
#                                                                  4  3      4
#      4  8        4  7        4  6        4  5          4  4   7⋅q ⋅z    7⋅q ⋅z
# 1.0⋅q ⋅z  + 4.0⋅q ⋅z  + 7.0⋅q ⋅z  + 7.0⋅q ⋅z  + 4.375⋅q ⋅z  + ─────── + ──────
#                                                                  4         16
#
# 2    4       4
#     q ⋅z    q         3    7         3    6         3    5         3    4   35
# ─ + ──── + ─── + 4.0⋅q ⋅s⋅z  + 14.0⋅q ⋅s⋅z  + 21.0⋅q ⋅s⋅z  + 17.5⋅q ⋅s⋅z  + ──
#      16    256
#
#   3    3       3    2      3        3
# ⋅q ⋅s⋅z    21⋅q ⋅s⋅z    7⋅q ⋅s⋅z   q ⋅s        3    6         3    5         3
# ──────── + ────────── + ──────── + ──── + 4.0⋅q ⋅t⋅z  + 12.0⋅q ⋅t⋅z  + 15.0⋅q
#   4            8           16       32
#
#                          3    2      3        3
#     4       3    3   15⋅q ⋅t⋅z    3⋅q ⋅t⋅z   q ⋅t        3  10         3  9
# ⋅t⋅z  + 10⋅q ⋅t⋅z  + ────────── + ──────── + ──── + 4.0⋅q ⋅z   + 12.0⋅q ⋅z  +
#                          4           4        16
#
#
#      3  8         3  7         3  6         3  5           3  4         3  3
# 9.0⋅q ⋅z  - 12.0⋅q ⋅z  - 31.5⋅q ⋅z  - 31.5⋅q ⋅z  - 17.375⋅q ⋅z  - 4.75⋅q ⋅z  -
#
#
#
#            3  2             3                 3        2  2  6         2  2  5
#  0.046875⋅q ⋅z  + 0.296875⋅q ⋅z + 0.05078125⋅q  + 6.0⋅q ⋅s ⋅z  + 18.0⋅q ⋅s ⋅z
#
#
#                                      2  2  2      2  2        2  2
#          2  2  4       2  2  3   45⋅q ⋅s ⋅z    9⋅q ⋅s ⋅z   3⋅q ⋅s          2
#  + 22.5⋅q ⋅s ⋅z  + 15⋅q ⋅s ⋅z  + ─────────── + ───────── + ─────── + 12.0⋅q ⋅s
#                                       8            8          32
#
#                                                            2            2
#     5         2      4       2      3       2      2   15⋅q ⋅s⋅t⋅z   3⋅q ⋅s⋅t
# ⋅t⋅z  + 30.0⋅q ⋅s⋅t⋅z  + 30⋅q ⋅s⋅t⋅z  + 15⋅q ⋅s⋅t⋅z  + ─────────── + ────────
#                                                             4           8
#
#
#         2    9         2    8         2    7         2    6         2    5
# + 12.0⋅q ⋅s⋅z  + 30.0⋅q ⋅s⋅z  + 12.0⋅q ⋅s⋅z  - 42.0⋅q ⋅s⋅z  - 73.5⋅q ⋅s⋅z  - 5
#
#
#
#       2    4          2    3          2    2             2                  2
# 7.75⋅q ⋅s⋅z  - 24.25⋅q ⋅s⋅z  - 4.125⋅q ⋅s⋅z  + 0.421875⋅q ⋅s⋅z + 0.1796875⋅q ⋅
#
#
#                                                              2  2
#          2  2  4       2  2  3      2  2  2      2  2     3⋅q ⋅t          2
# s + 6.0⋅q ⋅t ⋅z  + 12⋅q ⋅t ⋅z  + 9⋅q ⋅t ⋅z  + 3⋅q ⋅t ⋅z + ─────── + 12.0⋅q ⋅t⋅
#                                                              8
#
#
#  8       2    7         2    5         2    4         2    3        2    2
# z  + 24⋅q ⋅t⋅z  - 42.0⋅q ⋅t⋅z  - 52.5⋅q ⋅t⋅z  - 31.5⋅q ⋅t⋅z  - 8.5⋅q ⋅t⋅z  + 0
#
#
#
#       2                 2          2  12       2  11        2  10         2  9
# .125⋅q ⋅t⋅z + 0.359375⋅q ⋅t + 6.0⋅q ⋅z   + 12⋅q ⋅z   - 9.0⋅q ⋅z   - 45.0⋅q ⋅z
#
#
#
#            2  8         2  7           2  6           2  5               2  4
#  - 39.375⋅q ⋅z  + 13.5⋅q ⋅z  + 57.125⋅q ⋅z  + 54.875⋅q ⋅z  + 24.4765625⋅q ⋅z
#
#
#
#             2  3               2  2               2                    2
# + 1.609375⋅q ⋅z  - 2.34765625⋅q ⋅z  - 0.37890625⋅q ⋅z + 0.07568359375⋅q  + 4⋅q
#
#
#                                                     3        3
#   3  5         3  4         3  3        3  2   5⋅q⋅s ⋅z   q⋅s          2    4
# ⋅s ⋅z  + 10⋅q⋅s ⋅z  + 10⋅q⋅s ⋅z  + 5⋅q⋅s ⋅z  + ──────── + ──── + 12⋅q⋅s ⋅t⋅z
#                                                   4        8
#
#                                                   2
#         2    3         2    2        2       3⋅q⋅s ⋅t         2  8         2
# + 24⋅q⋅s ⋅t⋅z  + 18⋅q⋅s ⋅t⋅z  + 6⋅q⋅s ⋅t⋅z + ──────── + 12⋅q⋅s ⋅z  + 24⋅q⋅s ⋅z
#                                                 4
#
#
# 7           2  5           2  4           2  3          2  2            2
#   - 42.0⋅q⋅s ⋅z  - 52.5⋅q⋅s ⋅z  - 31.5⋅q⋅s ⋅z  - 9.5⋅q⋅s ⋅z  - 0.875⋅q⋅s ⋅z +
#
#
#                                                                   2
#             2           2  3           2  2          2     3⋅q⋅s⋅t
# 0.109375⋅q⋅s  + 12⋅q⋅s⋅t ⋅z  + 18⋅q⋅s⋅t ⋅z  + 9⋅q⋅s⋅t ⋅z + ──────── + 24⋅q⋅s⋅t
#                                                               2
#
#
#   7             6               5               4               3
# ⋅z  + 36⋅q⋅s⋅t⋅z  - 18.0⋅q⋅s⋅t⋅z  - 75.0⋅q⋅s⋅t⋅z  - 67.5⋅q⋅s⋅t⋅z  - 29.25⋅q⋅s⋅
#
#
#
#    2                                          11           10             9
# t⋅z  - 4.375⋅q⋅s⋅t⋅z + 0.4375⋅q⋅s⋅t + 12⋅q⋅s⋅z   + 18⋅q⋅s⋅z   - 27.0⋅q⋅s⋅z  -
#
#
#
#           8             7              6               5                4
# 76.5⋅q⋅s⋅z  - 40.5⋅q⋅s⋅z  + 47.25⋅q⋅s⋅z  + 88.625⋅q⋅s⋅z  + 63.4375⋅q⋅s⋅z  + 19
#
#
#
#              3                  2
# .734375⋅q⋅s⋅z  - 0.6484375⋅q⋅s⋅z  - 0.74609375⋅q⋅s⋅z + 0.240234375⋅q⋅s + 4⋅q⋅t
#
#
#
# 3  2        3        3         2  6         2  5           2  4           2  3
#  ⋅z  + 4⋅q⋅t ⋅z + q⋅t  + 12⋅q⋅t ⋅z  + 12⋅q⋅t ⋅z  - 15.0⋅q⋅t ⋅z  - 30.0⋅q⋅t ⋅z
#
#
#
#             2  2           2               2           10           9
#  - 18.75⋅q⋅t ⋅z  - 5.25⋅q⋅t ⋅z + 0.4375⋅q⋅t  + 12⋅q⋅t⋅z   + 12⋅q⋅t⋅z  - 33.0⋅q
#
#
#
#     8             7             6             5               4              3
# ⋅t⋅z  - 60.0⋅q⋅t⋅z  - 10.5⋅q⋅t⋅z  + 52.5⋅q⋅t⋅z  + 62.375⋅q⋅t⋅z  + 32.25⋅q⋅t⋅z
#
#
#
#                  2                                          14        13
#  + 3.609375⋅q⋅t⋅z  - 3.453125⋅q⋅t⋅z - 0.01953125⋅q⋅t + 4⋅q⋅z   + 4⋅q⋅z   - 17.
#
#
#
#      12           11           10            9              8           7
# 0⋅q⋅z   - 30.0⋅q⋅z   + 8.25⋅q⋅z   + 57.75⋅q⋅z  + 48.4375⋅q⋅z  - 8.25⋅q⋅z  - 49
#
#
#
#            6                5                  4                3
# .828125⋅q⋅z  - 44.015625⋅q⋅z  - 12.66796875⋅q⋅z  + 4.5078125⋅q⋅z  + 2.58105468
#
#
#                                                                      4  2    4
#       2                                          4  4      4  3   3⋅s ⋅z    s
# 75⋅q⋅z  - 0.4443359375⋅q⋅z - 0.018310546875⋅q + s ⋅z  + 2⋅s ⋅z  + ─────── + ──
#                                                                      2       2
#
#       4                                       3
# ⋅z   s       3    3      3    2      3       s ⋅t      3  7      3  6        3
# ── + ── + 4⋅s ⋅t⋅z  + 6⋅s ⋅t⋅z  + 3⋅s ⋅t⋅z + ──── + 4⋅s ⋅z  + 6⋅s ⋅z  - 3.0⋅s
#      16                                       2
#
#
#   5         3  4          3  3          3  2           3              3      2
# ⋅z  - 12.5⋅s ⋅z  - 11.25⋅s ⋅z  - 4.875⋅s ⋅z  - 1.0625⋅s ⋅z - 0.09375⋅s  + 6⋅s
#
#
#                         2  2
#   2  2      2  2     3⋅s ⋅t        2    6       2    5         2    4
# ⋅t ⋅z  + 6⋅s ⋅t ⋅z + ─────── + 12⋅s ⋅t⋅z  + 12⋅s ⋅t⋅z  - 15.0⋅s ⋅t⋅z  - 30.0⋅s
#                         2
#
#
# 2    3          2    2         2               2        2  10      2  9
#  ⋅t⋅z  - 18.75⋅s ⋅t⋅z  - 5.25⋅s ⋅t⋅z - 0.5625⋅s ⋅t + 6⋅s ⋅z   + 6⋅s ⋅z  - 16.5
#
#
#
#   2  8         2  7         2  6          2  5            2  4           2  3
# ⋅s ⋅z  - 30.0⋅s ⋅z  - 5.25⋅s ⋅z  + 26.25⋅s ⋅z  + 30.1875⋅s ⋅z  + 16.125⋅s ⋅z
#
#
#
#              2  2              2                  2        3          3
# + 3.3046875⋅s ⋅z  + 0.2734375⋅s ⋅z + 0.177734375⋅s  + 4⋅s⋅t ⋅z + 2⋅s⋅t  + 12⋅s
#
#
#
#   2  5        2  4           2  3           2  2           2              2
# ⋅t ⋅z  + 6⋅s⋅t ⋅z  - 18.0⋅s⋅t ⋅z  - 21.0⋅s⋅t ⋅z  - 8.25⋅s⋅t ⋅z - 1.125⋅s⋅t  +
#
#
#
#         9          8             7             6             5              4
# 12⋅s⋅t⋅z  + 6⋅s⋅t⋅z  - 36.0⋅s⋅t⋅z  - 42.0⋅s⋅t⋅z  + 10.5⋅s⋅t⋅z  + 47.25⋅s⋅t⋅z
#
#
#
#              3               2                                         13
# + 36.75⋅s⋅t⋅z  + 13.875⋅s⋅t⋅z  - 0.328125⋅s⋅t⋅z - 0.2890625⋅s⋅t + 4⋅s⋅z   + 2⋅
#
#
#
#    12           11           10            9             8            7
# s⋅z   - 18.0⋅s⋅z   - 21.0⋅s⋅z   + 18.75⋅s⋅z  + 48.375⋅s⋅z  + 23.25⋅s⋅z  - 19.8
#
#
#
#       6                5                 4                3                 2
# 75⋅s⋅z  - 36.890625⋅s⋅z  - 22.5703125⋅s⋅z  - 3.7578125⋅s⋅z  + 1.88671875⋅s⋅z
#
#
#
#                                         4      3  4        3  2      3
# - 0.1748046875⋅s⋅z + 0.08056640625⋅s + t  + 4⋅t ⋅z  - 6.0⋅t ⋅z  - 4⋅t ⋅z - 0.7
#
#
#
#    3      2  8         2  6       2  5          2  4         2  3          2
# 5⋅t  + 6⋅t ⋅z  - 18.0⋅t ⋅z  - 12⋅t ⋅z  + 11.25⋅t ⋅z  + 18.0⋅t ⋅z  + 9.375⋅t ⋅z
#
#
#
# 2         2                2        12           10         9            8
#   + 2.25⋅t ⋅z - 1.2890625⋅t  + 4⋅t⋅z   - 18.0⋅t⋅z   - 12⋅t⋅z  + 24.75⋅t⋅z  + 3
#
#
#
#        7           6           5                4            3
# 6.0⋅t⋅z  + 5.25⋅t⋅z  - 22.5⋅t⋅z  - 25.640625⋅t⋅z  - 10.75⋅t⋅z  + 1.6171875⋅t⋅z
#
#
#
# 2                                    16        14      13          12
#   + 2.578125⋅t⋅z + 0.5361328125⋅t + z   - 6.0⋅z   - 4⋅z   + 12.75⋅z   + 18.0⋅z
#
#
#
# 11          10          9               8         7               6
#    - 4.125⋅z   - 24.75⋅z  - 19.2890625⋅z  + 2.75⋅z  + 17.6484375⋅z  + 13.64062
#
#
#
#    5                 4              3                  2
# 5⋅z  + 1.0107421875⋅z  - 3.1171875⋅z  - 0.59326171875⋅z  + 0.4638671875⋅z - 0.
#
#
#
#
# 0514984130859375

# %%
# Photon_Sphere = 2*y**4 - 6*y**3 + 4*q*y**2 + 5*s*y + 6*t 

# Photon_Sphere_Substituted = expand(Photon_Sphere.subs(y,z2+(3/4)))

# 
# collect(Photon_Sphere_Substituted,z2)

# %%
qst_tuple = ( {q:1, s:1, t:1}, {q:1, s:-1, t:1}, {q:1, s:2, t:3}, {q:1, s:-2, t:3}, {q:2, s:1, t:3}, {q:2, s:-1, t:3} ) # set of q,s,t
qst_tuple
# Out:
# ({q: 1, s: 1, t: 1}, {q: 1, s: -1, t: 1}, {q: 1, s: 2, t: 3}, {q: 1, s: -2, t:
#  3}, {q: 2, s: 1, t: 3}, {q: 2, s: -1, t: 3})

# %%
A = 1 - (2*M/r) + (q*M**2/r**2) + (s*M**3/r**3) + (t*M**4/r**4) # g_{tt}

Eq(A,0)
# Out:
#  4      3      2
# M ⋅t   M ⋅s   M ⋅q   2⋅M
# ──── + ──── + ──── - ─── + 1 = 0
#   4      3      2     R
#  R      R      R

# %%
photon_sphere_radius = ( (3/4) + sqrt( ( 2*sqrt( 25 - 192*t ) - 1 ) / (16) ) )*M

Eq(photon_sphere_radius,0) #Just to show the expression, it's not an equation
# Out:
#   ⎛     _____________________       ⎞
#   ⎜    ╱   ____________             ⎟
#   ⎜   ╱  ╲╱ 25 - 192⋅t    1         ⎟
# M⋅⎜  ╱   ────────────── - ──  + 0.75⎟ = 0
#   ⎝╲╱          8          16        ⎠

# %%
A_Photon_Sphere = expand(A.subs(r,(photon_sphere_radius))) # g_{tt} at the photon sphere
simplify(A_Photon_Sphere)
Eq(A_Photon_Sphere,0)
# Out:
#                           q
# ───────────────────────────────────────────────────── + ──────────────────────
#                           _____________________                             __
#   ____________           ╱   ____________                                  ╱
# ╲╱ 25 - 192⋅t           ╱  ╲╱ 25 - 192⋅t    1             ____________    ╱  ╲
# ────────────── + 1.5⋅  ╱   ────────────── - ──  + 0.5   ╲╱ 25 - 192⋅t ⋅  ╱   ─
#       8              ╲╱          8          16                         ╲╱
#                                                         ──────────────────────
#                                                                             8
#
#                                  s
# ──────────────────────────────────────────────────────────────────────────────
# ___________________
#  ____________
# ╱ 25 - 192⋅t    1                                         ____________________
# ───────────── - ──                                       ╱   ____________
#      8          16              ____________            ╱  ╲╱ 25 - 192⋅t    1
# ─────────────────── + 0.28125⋅╲╱ 25 - 192⋅t  + 1.625⋅  ╱   ────────────── - ──
#                                                      ╲╱          8          16
#
#                                                                         t
# ─────────── + ────────────────────────────────────────────────────────────────
#                                                _____________________
#                                               ╱   ____________
# _                            ____________    ╱  ╲╱ 25 - 192⋅t    1
#               -3⋅t + 0.375⋅╲╱ 25 - 192⋅t ⋅  ╱   ────────────── - ──  + 0.40625
#                                           ╲╱          8          16
#   + 0.28125
#
#
#                                                                              2
# ────────────────────────────────────────────────────── + 1 - ─────────────────
#                            _____________________                  ____________
#                           ╱   ____________                       ╱   _________
#    ____________          ╱  ╲╱ 25 - 192⋅t    1                  ╱  ╲╱ 25 - 192
# ⋅╲╱ 25 - 192⋅t  + 1.5⋅  ╱   ────────────── - ──  + 0.5         ╱   ───────────
#                       ╲╱          8          16              ╲╱          8
#
#
#
#
# ──────────────── = 0
# _________
# ___
# ⋅t    1
# ─── - ──  + 0.75
#       16

# %%
A_Photon_Sphere_Substituted = A_Photon_Sphere.subs({q:1, s:1, t:1}) # g_{tt} at photn sphere for (q,s,t) = (1,1,1)

Eq(A_Photon_Sphere_Substituted,0)
# Out:
#                       1
# 1 + ────────────────────────────────────── + ─────────────────────────────────
#                   _______________                                 ____________
#                  ╱   1    √167⋅ⅈ    √167⋅ⅈ                       ╱   1    √167
#     0.5 + 1.5⋅  ╱  - ── + ──────  + ──────             √167⋅ⅈ⋅  ╱  - ── + ────
#               ╲╱     16     8         8                       ╲╱     16     8
#                                              0.28125 + ───────────────────────
#                                                                    8
#
#        1
# ──────────────────────────────────────────────── + ───────────────────────────
# ___                                                               ____________
# ⋅ⅈ                                                               ╱   1    √167
# ──              _______________                    -2.5 + 1.5⋅  ╱  - ── + ────
#                ╱   1    √167⋅ⅈ                                ╲╱     16     8
# ─── + 1.625⋅  ╱  - ── + ──────  + 0.28125⋅√167⋅ⅈ
#             ╲╱     16     8
#
#              1                                                        2
# ─────────────────────────────────────────────────────── - ────────────────────
# ___                    _______________                               _________
# ⋅ⅈ                    ╱   1    √167⋅ⅈ                               ╱   1    √
# ──  + 0.375⋅√167⋅ⅈ⋅  ╱  - ── + ──────  + 0.40625⋅√167⋅ⅈ   0.75 +   ╱  - ── + ─
#                    ╲╱     16     8                               ╲╱     16
#
#
#
#
# ────── = 0
# ______
# 167⋅ⅈ
# ─────
#  8

# %%
from sympy import*
q,s,t,z = symbols("q,s,t,z")

def horizon(q,s,t):
    
    equation_of_horizon = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))
    horizon_qst_substituted = equation_of_horizon.subs({q:q,s:s,t:t})
    horizons = solve(horizon_qst_substituted)
    horizon_list = []
    for horizon in horizons:
        hr = horizon
        if hr.is_positive and hr.is_real:
            horizon_list.append(hr)
            if len(horizon_list)>0:       
                m = max(horizon_list)
    return (m)

def photon_sphere(q,s,t):
    
    equation_of_photonsphere = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))
    ps_qst_substituted = equation_of_photonsphere.subs({q:q,s:s,t:t})
    photonspheres = solve(ps_qst_substituted)
    photonsphere_list = []
    for photonsphere in photonspheres:
        ps = photonsphere
        if ps.is_positive and ps.is_real:
            photonsphere_list.append(ps)
            if len(photonsphere_list)>0:       
                m = max(photonsphere_list)
    return(m)
  
    
test_hr = horizon(5/2,-1/2,-19/16)
test_ps = photon_sphere(5/2,-1/2,-19/16)
print(test_hr)
print(test_ps)
# Out:
# 0.569840290998053
# 0.633869275707726

# %%
from sympy import*

q,s,t,z = symbols("q,s,t,z")

def horizon(q,s,t):
    
    equation_for_horizon = z**4 + (q-3/2)*(z**2) \
        + (q+s-1)*z + ((q/4) + (s/2) + t - (3/16))
    
    horizon_at_qst = \
        equation_for_horizon.subs({q:q,s:s,t:t})
    
    horizons = solve(horizon_at_qst)

    list_of_horizons = []

    for horizon in horizons:
        if horizon.is_positive and horizon.is_real:
            list_of_horizons.append(horizon)
            if len(list_of_horizons)>0:       
                maximum_of_horizons = \
                max(list_of_horizons)

    return (maximum_of_horizons)

def photon_sphere(q,s,t):
    
    equation_for_photonsphere = \
        z**4(2*q-(27/8))*(z**2) \
        + (3*q + (5/2)*s(27/8))*z \
        + ((9/8)*q + (15/8)*s + 3*t - (243/256))
    
    photon_sphere_at_qst = \
        equation_for_photonsphere.subs({q:q,s:s,t:t})
    
    photonspheres = solve(photon_sphere_at_qst)
    
    list_of_photon_spheres = []

    for photon_sphere in photonspheres:

        if photon_sphere.is_positive and photon_sphere.is_real:

            list_of_photon_spheres.append(photon_sphere)

            if len(list_of_photon_spheres)>0:  

                return max(list_of_photon_spheres)
  
    
hr = horizon(5/2,-1/2,-19/16)
#ps = photon_sphere(5/2,-1/2,-19/16)
print(hr)
# Out:
# 0.569840290998053
# <>:29: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:29: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /var/folders/5v/jgblmv2j1px1sz8pnpx8jqxh0000gn/T/ipykernel_3742/2619929350.py:29: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   z**4(2*q-(27/8))*(z**2) \

# %%
from sympy import symbols,solve
q,s,t,r = symbols("q,s,t,r")
g_tt = 1 + (2/r) + (q/r**2) + (s/r**3) + (t/r**4)
Horizon_Equation = g_tt.subs({q:3/2,s:1/2,t:9/16})
horizons = solve(Horizon_Equation)
h1 = []
for horizon in horizons:
    hr = horizon
    if hr.is_positive and hr.is_real:
        print(hr)
        h1.append(hr)
        
if len(h1)>0:       
    z = max(h1)
    print(z)

# %%
def photon_sphere(q,s,t):
    equation_of_photonsphere = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))
    equation_of_photonsphere_qst_substituted = equation_of_photonsphere.subs(({q:q,s:s,t:t}))
    print(equation_of_photonsphere_qst_substituted)
    photon_spheres = solve(equation_of_photonsphere_qst_substituted,z)
    return photon_spheres

# %%
from sympy import*
q,s,t,z = symbols("q,s,t,z")
a,b,c = symbols("a,b,c")

Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)

Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c)

Delta_HR = Delta.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)-(3/16))})

Lambda_HR = Lambda.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)-(3/16))})

Delta_PS = Delta.subs({a:(2*q)-(27/8),b:5*(s/2)+(3*q)-(27/8),c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})

Lambda_PS = Lambda.subs({a:(2*q)-(27/8),b:5*(s/2)+(3*q)-(27/8),c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})

equation_of_horizon = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))

equation_of_photonsphere = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))

"""print("a:",(2*q)-(27/8),"b:",5*(s/2)+(3*q)-(27/8),"c:",(15/8)*s+(9/8)*q+(3*t)-(243/256))
print("a:",q-(3/2),"b:",(q+s-1),c:((s/2)+(q/4)-(3/16))})
print("Horizon Equation : ",equation_of_horizon)
print("Equation of Photon Sphere : ",equation_of_photonsphere)
print("Delta for Photon Sphere : ",Delta_PS)
print("Delta for Horizon : ",Delta_HR)
print("Lambda for Horizon : ",Lambda_HR)
print("Lambda for Photon Sphere : ", Lambda_PS)
"""
# Out:
# 'print("a:",(2*q)-(27/8),"b:",5*(s/2)+(3*q)-(27/8),"c:",(15/8)*s+(9/8)*q+(3*t)-(243/256))\nprint("a:",q-(3/2),"b:",(q+s-1),c:((s/2)+(q/4)-(3/16))})\nprint("Horizon Equation : ",equation_of_horizon)\nprint("Equation of Photon Sphere : ",equation_of_photonsphere)\nprint("Delta for Photon Sphere : ",Delta_PS)\nprint("Delta for Horizon : ",Delta_HR)\nprint("Lambda for Horizon : ",Lambda_HR)\nprint("Lambda for Photon Sphere : ", Lambda_PS)\n'

# %%
def frange(start,final,interval):
    
    numbers = []
    
    while start < final:
        numbers.append(start)
        start = start + interval
    return numbers

# %%
a,b,c = symbols("a,b,c")
Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)
Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c) 
print(Delta)
print(Lambda)
# Out:
# 16*a**4*c - 4*a**3*b**2 - 128*a**2*c**2 + 144*a*b**2*c - 27*b**4 + 256*c**3
# -2*a**3 + 8*a*c - 9*b**2

# %%
from sympy import*
q,s,t,z = symbols("q,s,t,z")
a,b,c = symbols("a,b,c")

Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)

Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c)

Delta_HR = Delta.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)-(3/16))})

Lambda_HR = Lambda.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)-(3/16))})

Delta_PS = Delta.subs({a:(2*q)-(27/8),b:5*(s/2)+(3*q)-(27/8),c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})

Lambda_PS = Lambda.subs({a:(2*q)-(27/8),b:5*(s/2)+(3*q)-(27/8),c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})

equation_of_horizon = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))

equation_of_photonsphere = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))

print("a:",(2*q)-(27/8),"b:",5*(s/2)+(3*q)-(27/8),"c:",(15/8)*s+(9/8)*q+(3*t)-(243/256))

print("a:",q-(3/2),"b:",(q+s-1),"c:",((s/2)+(q/4)-(3/16)))
print("Horizon Equation : ",equation_of_horizon)
print("Equation of Photon Sphere : ",equation_of_photonsphere)
print("Delta for Photon Sphere : ",Delta_PS)
print("Delta for Horizon : ",Delta_HR)
print("Lambda for Horizon : ",Lambda_HR)
print("Lambda for Photon Sphere : ", Lambda_PS)
# Out:
# a: 2*q - 3.375 b: 3*q + 5*s/2 - 3.375 c: 1.125*q + 1.875*s + 3*t - 0.94921875
# a: q - 1.5 b: q + s - 1 c: q/4 + s/2 - 0.1875
# Horizon Equation :  q/4 + s/2 + t + z**4 + z**2*(q - 1.5) + z*(q + s - 1) - 0.1875
# Equation of Photon Sphere :  1.125*q + 1.875*s + 3*t + z**4 + z**2*(2*q - 3.375) + z*(3*q + 2.5*s - 3.375) - 0.94921875
# Delta for Photon Sphere :  2075.94140625*(0.592592592592593*q - 1)**4*(1.125*q + 1.875*s + 3*t - 0.94921875) - 1751.57556152344*(0.592592592592593*q - 1)**3*(0.888888888888889*q + 0.740740740740741*s - 1)**2 - 13122.0*(0.592592592592593*q - 1)**2*(0.375*q + 0.625*s + t - 0.31640625)**2 + 1640.25*(2*q - 3.375)*(0.888888888888889*q + 0.740740740740741*s - 1)**2*(1.125*q + 1.875*s + 3*t - 0.94921875) - 3503.15112304688*(0.888888888888889*q + 0.740740740740741*s - 1)**4 + 6912*(0.375*q + 0.625*s + t - 0.31640625)**3
# Delta for Horizon :  81.0*(0.666666666666667*q - 1)**4*(q/4 + s/2 - 0.1875) - 13.5*(0.666666666666667*q - 1)**3*(q + s - 1)**2 - 72.0*(0.666666666666667*q - 1)**2*(q/2 + s - 0.375)**2 + 144*(q - 1.5)*(q/4 + s/2 - 0.1875)*(q + s - 1)**2 + 32*(q/2 + s - 0.375)**3 - 27*(q + s - 1)**4
# Lambda for Horizon :  -6.75*(0.666666666666667*q - 1)**3 + 8*(q - 1.5)*(q/4 + s/2 - 0.1875) - 9*(q + s - 1)**2
# Lambda for Photon Sphere :  -76.88671875*(0.592592592592593*q - 1)**3 + 8*(2*q - 3.375)*(1.125*q + 1.875*s + 3*t - 0.94921875) - 102.515625*(0.888888888888889*q + 0.740740740740741*s - 1)**2

# %%
from sympy import*
import math
q,s,t,z = symbols("q,s,t,z")
a,b,c,r = symbols("a,b,c,r")

def horizon(q,s,t):
    
    equation_for_horizon = z**4 + (q-3/2)*(z**2) +(q+s-1)*z \
    + ((q/4) + (s/2) + t - (3/16))
    
    horizon_at_qst = equation_for_horizon.subs({q:q,s:s,t:t})
    horizons = solve(horizon_at_qst)
    list_of_horizons = []
    for horizon in horizons:
        if horizon.is_positive and horizon.is_real:
            list_of_horizons.append(horizon)
            if len(list_of_horizons)>0:       
                return (max(list_of_horizons) + 1/2)

def photon_sphere(q,s,t):
    
    equation_for_photonsphere = z**4 + (2*q-(27/8))*(z**2)\
    + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))
    
    photon_sphere_at_qst = equation_for_photonsphere.subs({q:q,s:s,t:t})
    photon_spheres = solve(photon_sphere_at_qst)
    list_of_photon_spheres = []
    for photon_sphere in photon_spheres:
        if photon_sphere.is_positive and photon_sphere.is_real:
            list_of_photon_spheres.append(photon_sphere)
            if len(list_of_photon_spheres)>0:       
                return (max(list_of_photon_spheres) + 3/4)
                

def shadow_radius(q,s,t):
    g_tt = 1 - 2/r + q/r**2 + s/r**3+ t/r**4
    photonsphere = photon_sphere(q,s,t)
    shadow_radius = photonsphere/math.sqrt(g_tt.subs({r:photonsphere}))
    return shadow_radius
    
test_hr_2 = horizon(5/2,-1/2,-19/16)
test_ps_2 = photon_sphere(5/2,-1/2,-19/16)
test_sr_2 = shadow_radius(5/2,-1/2,-19/16)

print(test_hr_2)
print(test_ps_2)
print(test_sr_2)
# Out:
# 1.06984029099805
# 1.38386927570773
# 2.34671790606773

# %%
import math
gravitational_constant = 6.67*math.pow(10,-11)
mass_of_SgrA = 4*math.pow(10,6)*(1.99)*math.pow(10,30)
distance_to_SgrA = 8.00*(3.09)*math.pow(10,19)
mass_of_M87 = (6.50)*(10**9)*(1.99)*math.pow(10,30)
distance_to_M87 = (16.80)*(3.09)*math.pow(10,22)
speed_of_light = 3*(math.pow(10,8))
radian_to_microarcsecond = 19.8/(0.9595*math.pow(10,-10))

def angular_diameter_M87_assuming_Schwz():

    angular_diameter_of_M87 = 2*3*math.sqrt(3)*gravitational_constant* \
        (mass_of_M87)*(1/distance_to_M87)*(1/speed_of_light**2)*radian_to_microarcsecond
    
    return angular_diameter_of_M87

def angular_diameter_SgrA_assuming_Schwz():

    angular_diameter_of_SgrA = 2*3*math.sqrt(3)*gravitational_constant* \
        (mass_of_SgrA)*(1/speed_of_light**2)*(1/distance_to_SgrA)*radian_to_microarcsecond
    
    return angular_diameter_of_SgrA

ad_M87 = angular_diameter_M87_assuming_Schwz()
print(ad_M87)

ad_SgrA = angular_diameter_SgrA_assuming_Schwz()
print(ad_SgrA)
# Out:
# 39.60172332839777
# 51.17761168592942

# %%
a,b,c = symbols("a,b,c")

Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) \
      - 128*(a**2)*(c**2) + 256*(c**3)

Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c) 

print(Delta)
print(Lambda)
# Out:
# 16*a**4*c - 4*a**3*b**2 - 128*a**2*c**2 + 144*a*b**2*c - 27*b**4 + 256*c**3
# -2*a**3 + 8*a*c - 9*b**2

# %%
from sympy import*

q,s,t,z = symbols("q,s,t,z")
a,b,c = symbols("a,b,c")

Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + \
    144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)

Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c)

def Delta_at_photonsphere(q,s,t):
    delta_ps = Delta.subs({a:(2*q)-(27/8), b:5*(s/2)+(3*q)-(27/8), c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})
    return delta_ps.subs({q:q,s:s,t:t})
    

def Delta_at_horizon(q,s,t):
    delta_hr = Delta.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)+(t)-(3/16))})
    return delta_hr.subs({q:q,s:s,t:t})
    

def Lambda__at_horizon(q,s,t):
    Lambda_horizon = Lambda.subs({a:q-(3/2),b:(q+s-1),c:((s/2)+(q/4)+(t)-(3/16))})
    return Lambda_horizon.subs({q:q,s:s,t:t})
    

def Lambda_at_photonsphere(q,st):
    Lambda_photonsphere = Lambda.subs({a:(2*q)-(27/8),b:5*(s/2)+(3*q)-(27/8),c:(15/8)*s+(9/8)*q+(3*t)-(243/256)})
    return Lambda_photonsphere.subs({q:q,s:s,t:t})
    

equation_for_horizon = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))

equation_for_photonsphere = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + \
    ((9/8)*q + (15/8)*s + 3*t- (243/256))

print("a:", (2*q)-(27/8), "b:", 5*(s/2)+(3*q)-(27/8), "c:", (15/8)*s+(9/8)*q+(3*t)-(243/256))

print("a:",q-(3/2),"b:",(q+s-1),"c:",((s/2)+(q/4)-(3/16)))
# Out:
# a: 2*q - 3.375 b: 3*q + 5*s/2 - 3.375 c: 1.125*q + 1.875*s + 3*t - 0.94921875
# a: q - 1.5 b: q + s - 1 c: q/4 + s/2 - 0.1875
