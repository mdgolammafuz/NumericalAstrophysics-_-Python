# %%
print('hello, world again! mafuz is here!')
# Out:
# hello, world again! mafuz is here!

# %%
from sympy import symbols,Symbol,solve
q,s,t,r = symbols("q,s,t,r")
g_tt = 1 + (2/r) + (q/r**2) + (s/r**3) + (t/r**4)
Horizon_Equation = g_tt.subs({q:1,s:1,t:1})
horizons = solve(Horizon_Equation,dict=True)
for horizon in horizons:
   print(horizon)
# Out:
# {r: -1}
# {r: -1/3 - 1/(3*(-1/2 - sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)/3}
# {r: -1/3 - (-1/2 + sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3)/3 - 1/(3*(-1/2 + sqrt(3)*I/2)*(3*sqrt(93)/2 + 29/2)**(1/3))}
# {r: -(3*sqrt(93)/2 + 29/2)**(1/3)/3 - 1/3 - 1/(3*(3*sqrt(93)/2 + 29/2)**(1/3))}

# %%
# Expression for Delta in terms of a,b,c:
a,b,c = symbols("a,b,c")
Delta = - 4*(a**3)*(b**2) + 16*(a**4)*(c) - 27*(b**4) + 144*(a)*(b**2)*(c) - 128*(a**2)*(c**2) + 256*(c**3)
Lambda = - 2*(a**3) - 9*(b**2) + 8*(a)*(c)

# %%
z=symbols("z")

# Horizon equation
z1 = z**4 + (2*q-3)*(z**2) +(q+s-1)*z + (q/4) + (s/2) + t - (3/16)

#Photon Sphere Equation
z2 = z**4 + (16*q-27)*(z**2) + (24*q + 20*s -27)*z + 9*q + 15*s + 3*t- (243/256)

# %%
x = Symbol('x')
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')

# %%
expr = a*x*x + b*x + c
solve(expr, x)
# Out:
# ⎡        _____________          _____________⎤
# ⎢       ╱           2          ╱           2 ⎥
# ⎢-b - ╲╱  -4⋅a⋅c + b    -b + ╲╱  -4⋅a⋅c + b  ⎥
# ⎢─────────────────────, ─────────────────────⎥
# ⎣         2⋅a                    2⋅a         ⎦

# %%
from sympy import Symbol, solve, pprint
s = Symbol('s')
u = Symbol('u')
t = Symbol('t')
a = Symbol('a')
expr = u*t + (1/2)*a*t*t - s
t_expr = solve(expr,t)
t_expr
# Out:
# ⎡                        ______________                          _____________
# ⎢                       ╱            2                          ╱            2
# ⎢-u - 1.4142135623731⋅╲╱  a⋅s + 0.5⋅u    -u + 1.4142135623731⋅╲╱  a⋅s + 0.5⋅u
# ⎢──────────────────────────────────────, ─────────────────────────────────────
# ⎣                  a                                       a
#
# _⎤
#  ⎥
#  ⎥
# ─⎥
#  ⎦

# %%
from sympy import symbols,Symbol,solve
r=Symbol("r")
First_Energy_Condition = Q*(r**2) + 2*r*R + 3*T

Roots_First_Energy_Condition = solveset (Eq(First_Energy_Condition,0),r)

simplify(Roots_First_Energy_Condition)
# Out:
# ⎧        _____________          _____________⎫
# ⎪       ╱           2          ╱           2 ⎪
# ⎨-R - ╲╱  -3⋅Q⋅T + R    -R + ╲╱  -3⋅Q⋅T + R  ⎬
# ⎪─────────────────────, ─────────────────────⎪
# ⎩          Q                      Q          ⎭

# %%
Third_Energy_Condition = 2*Q*r**2 + 5*r*R + 9*T

Roots_Third_Energy_Condition = solveset (Eq(Third_Energy_Condition,0),r)

simplify(Roots_Third_Energy_Condition)
# Out:
# ⎧          _________________            _________________⎫
# ⎪         ╱               2            ╱               2 ⎪
# ⎨-5⋅R - ╲╱  -72⋅Q⋅T + 25⋅R    -5⋅R + ╲╱  -72⋅Q⋅T + 25⋅R  ⎬
# ⎪───────────────────────────, ───────────────────────────⎪
# ⎩            4⋅Q                          4⋅Q            ⎭

# %%
#######Horizon = x**4 - 2*x**3 + q*x**2 + s*x + t 

#Horizon_Substituted = expand(Horizon.subs(x,z1+(1/2))) 

#collect(Horizon_Substituted, z1)
# Out:
#                                                 4  4      4  3    4  2    4
#     4  8       4  7       4  6       4  5   17⋅q ⋅z    5⋅q ⋅z    q ⋅z    q ⋅z
# 16⋅q ⋅z  + 32⋅q ⋅z  + 32⋅q ⋅z  + 20⋅q ⋅z  + ──────── + ─────── + ───── + ────
#                                                2          2        2      16
#
#     4                                                           3    3
#    q        3    7       3    6       3    5       3    4   25⋅q ⋅s⋅z       3
# + ─── + 32⋅q ⋅s⋅z  + 64⋅q ⋅s⋅z  + 60⋅q ⋅s⋅z  + 34⋅q ⋅s⋅z  + ────────── + 3⋅q ⋅
#   256                                                           2
#
#           3        3
#    2   7⋅q ⋅s⋅z   q ⋅s       3    6       3    5       3    4       3    3   9
# s⋅z  + ──────── + ──── + 32⋅q ⋅t⋅z  + 48⋅q ⋅t⋅z  + 36⋅q ⋅t⋅z  + 16⋅q ⋅t⋅z  + ─
#           16       32
#
#   3    2      3        3
# ⋅q ⋅t⋅z    3⋅q ⋅t⋅z   q ⋅t       3  10       3  9       3  8        3  7
# ──────── + ──────── + ──── + 32⋅q ⋅z   + 48⋅q ⋅z  - 60⋅q ⋅z  - 160⋅q ⋅z  - 157
#    2          4        16
#
#
#     3  6          3  5            3  4         3  3            3  2
# .5⋅q ⋅z  - 92.25⋅q ⋅z  - 32.1875⋅q ⋅z  - 5.75⋅q ⋅z  + 0.21875⋅q ⋅z  + 0.296875
#
#
#
#   3                 3       2  2  6       2  2  5       2  2  4       2  2  3
# ⋅q ⋅z + 0.05078125⋅q  + 24⋅q ⋅s ⋅z  + 48⋅q ⋅s ⋅z  + 42⋅q ⋅s ⋅z  + 21⋅q ⋅s ⋅z
#
#
#       2  2  2      2  2        2  2
#   51⋅q ⋅s ⋅z    9⋅q ⋅s ⋅z   3⋅q ⋅s        2      5       2      4       2
# + ─────────── + ───────── + ─────── + 48⋅q ⋅s⋅t⋅z  + 72⋅q ⋅s⋅t⋅z  + 48⋅q ⋅s⋅t⋅
#        8            8          32
#
#                         2            2
#  3       2      2   15⋅q ⋅s⋅t⋅z   3⋅q ⋅s⋅t       2    9       2    8       2
# z  + 18⋅q ⋅s⋅t⋅z  + ─────────── + ──────── + 48⋅q ⋅s⋅z  + 72⋅q ⋅s⋅z  - 96⋅q ⋅s
#                          4           8
#
#
#   7        2    6           2    5            2    4          2    3         2
# ⋅z  - 246⋅q ⋅s⋅z  - 221.25⋅q ⋅s⋅z  - 115.125⋅q ⋅s⋅z  - 34.25⋅q ⋅s⋅z  - 4.25⋅q
#
#
#
#     2             2                  2         2  2  4       2  2  3       2
# ⋅s⋅z  + 0.421875⋅q ⋅s⋅z + 0.1796875⋅q ⋅s + 24⋅q ⋅t ⋅z  + 24⋅q ⋅t ⋅z  + 12⋅q ⋅t
#
#
#                       2  2
# 2  2      2  2     3⋅q ⋅t        2    8       2    7        2    6        2
#  ⋅z  + 3⋅q ⋅t ⋅z + ─────── + 48⋅q ⋅t⋅z  + 48⋅q ⋅t⋅z  - 120⋅q ⋅t⋅z  - 186⋅q ⋅t⋅
#                       8
#
#
#  5           2    4         2    3         2    2          2                 2
# z  - 128.25⋅q ⋅t⋅z  - 51.0⋅q ⋅t⋅z  - 8.75⋅q ⋅t⋅z  + 0.125⋅q ⋅t⋅z + 0.359375⋅q
#
#
#
#          2  12       2  11        2  10        2  9           2  8          2
# ⋅t + 24⋅q ⋅z   + 24⋅q ⋅z   - 132⋅q ⋅z   - 189⋅q ⋅z  + 87.375⋅q ⋅z  + 309.0⋅q ⋅
#
#
#
#  7           2  6            2  5              2  4            2  3
# z  + 294.25⋅q ⋅z  + 159.125⋅q ⋅z  + 39.078125⋅q ⋅z  - 2.03125⋅q ⋅z  - 2.90625⋅
#
#
#
#  2  2               2                    2        3  5         3  4         3
# q ⋅z  - 0.37890625⋅q ⋅z + 0.07568359375⋅q  + 8⋅q⋅s ⋅z  + 16⋅q⋅s ⋅z  + 13⋅q⋅s ⋅
#
#
#            3  2        3        3
#  3   11⋅q⋅s ⋅z    5⋅q⋅s ⋅z   q⋅s          2    4         2    3         2    2
# z  + ────────── + ──────── + ──── + 24⋅q⋅s ⋅t⋅z  + 36⋅q⋅s ⋅t⋅z  + 21⋅q⋅s ⋅t⋅z
#          2           4        8
#
#                      2
#         2       3⋅q⋅s ⋅t         2  8         2  7         2  6          2  5
#  + 6⋅q⋅s ⋅t⋅z + ──────── + 24⋅q⋅s ⋅z  + 36⋅q⋅s ⋅z  - 51⋅q⋅s ⋅z  - 126⋅q⋅s ⋅z
#                    4
#
#
#             2  4            2  3              2  2            2
# - 102.75⋅q⋅s ⋅z  - 45.75⋅q⋅s ⋅z  - 11.1875⋅q⋅s ⋅z  - 0.875⋅q⋅s ⋅z + 0.109375⋅q
#
#
#                                                         2
#   2           2  3           2  2          2     3⋅q⋅s⋅t              7
# ⋅s  + 24⋅q⋅s⋅t ⋅z  + 24⋅q⋅s⋅t ⋅z  + 9⋅q⋅s⋅t ⋅z + ──────── + 48⋅q⋅s⋅t⋅z  + 48⋅q
#                                                     2
#
#
#       6              5              4                3               2
# ⋅s⋅t⋅z  - 126⋅q⋅s⋅t⋅z  - 189⋅q⋅s⋅t⋅z  - 111.0⋅q⋅s⋅t⋅z  - 36.0⋅q⋅s⋅t⋅z  - 4.375
#
#
#                                                                           8
#                                   11           10            9   381⋅q⋅s⋅z
# ⋅q⋅s⋅t⋅z + 0.4375⋅q⋅s⋅t + 24⋅q⋅s⋅z   + 24⋅q⋅s⋅z   - 135⋅q⋅s⋅z  - ────────── +
#                                                                      2
#
#
#            7              6                5                 4
# 105.0⋅q⋅s⋅z  + 324.0⋅q⋅s⋅z  + 271.625⋅q⋅s⋅z  + 127.9375⋅q⋅s⋅z  + 25.96875⋅q⋅s⋅
#
#
#
#  3                2                                             3  2        3
# z  - 1.59375⋅q⋅s⋅z  - 0.74609375⋅q⋅s⋅z + 0.240234375⋅q⋅s + 8⋅q⋅t ⋅z  + 4⋅q⋅t ⋅
#
#
#
#        3         2  6         2  5         2  4         2  3           2  2
# z + q⋅t  + 24⋅q⋅t ⋅z  + 12⋅q⋅t ⋅z  - 69⋅q⋅t ⋅z  - 60⋅q⋅t ⋅z  - 25.5⋅q⋅t ⋅z  -
#
#
#
#         2               2           10           9            8            7
# 5.25⋅q⋅t ⋅z + 0.4375⋅q⋅t  + 24⋅q⋅t⋅z   + 12⋅q⋅t⋅z  - 141⋅q⋅t⋅z  - 120⋅q⋅t⋅z  +
#
#
#
#             6              5                4             3                2
#  165.0⋅q⋅t⋅z  + 241.5⋅q⋅t⋅z  + 150.875⋅q⋅t⋅z  + 52.5⋅q⋅t⋅z  - 0.28125⋅q⋅t⋅z  -
#
#
#
#                                         14        13         12         11
#  3.453125⋅q⋅t⋅z - 0.01953125⋅q⋅t + 8⋅q⋅z   + 4⋅q⋅z   - 71⋅q⋅z   - 60⋅q⋅z   + 1
#
#
#
#         10             9              8            7                6
# 90.5⋅q⋅z   + 246.75⋅q⋅z  - 65.5625⋅q⋅z  - 271.5⋅q⋅z  - 247.78125⋅q⋅z  - 121.70
#
#
#
#         5                  4                3                  2
# 3125⋅q⋅z  - 11.61328125⋅q⋅z  + 12.265625⋅q⋅z  + 2.146484375⋅q⋅z  - 0.444335937
#
#
#                                                 4  2    4      4
#                             4  4      4  3   3⋅s ⋅z    s ⋅z   s       3    3
# 5⋅q⋅z - 0.018310546875⋅q + s ⋅z  + 2⋅s ⋅z  + ─────── + ──── + ── + 4⋅s ⋅t⋅z  +
#                                                 2       2     16
#
#                          3                                       3  4
#     3    2      3       s ⋅t      3  7      3  6      3  5   43⋅s ⋅z
#  6⋅s ⋅t⋅z  + 3⋅s ⋅t⋅z + ──── + 4⋅s ⋅z  + 6⋅s ⋅z  - 9⋅s ⋅z  - ──────── - 15.75⋅
#                          2                                      2
#
#                                                                              2
#  3  3          3  2           3              3      2  2  2      2  2     3⋅s
# s ⋅z  - 5.625⋅s ⋅z  - 1.0625⋅s ⋅z - 0.09375⋅s  + 6⋅s ⋅t ⋅z  + 6⋅s ⋅t ⋅z + ────
#                                                                              2
#
#   2
# ⋅t        2    6       2    5       2    4       2    3          2    2
# ─── + 12⋅s ⋅t⋅z  + 12⋅s ⋅t⋅z  - 33⋅s ⋅t⋅z  - 48⋅s ⋅t⋅z  - 23.25⋅s ⋅t⋅z  - 5.25
#
#
#                                                  2  8
#   2               2        2  10      2  9   69⋅s ⋅z        2  7          2  6
# ⋅s ⋅t⋅z - 0.5625⋅s ⋅t + 6⋅s ⋅z   + 6⋅s ⋅z  - ──────── - 48⋅s ⋅z  + 30.75⋅s ⋅z
#                                                 2
#
#
#           2  5            2  4         2  3              2  2              2
#  + 84.75⋅s ⋅z  + 61.6875⋅s ⋅z  + 24.0⋅s ⋅z  + 4.1484375⋅s ⋅z  + 0.2734375⋅s ⋅z
#
#
#
#                 2        3          3         2  5        2  4         2  3
#  + 0.177734375⋅s  + 4⋅s⋅t ⋅z + 2⋅s⋅t  + 12⋅s⋅t ⋅z  + 6⋅s⋅t ⋅z  - 36⋅s⋅t ⋅z  -
#
#
#
#       2  2           2              2           9          8           7
# 30⋅s⋅t ⋅z  - 8.25⋅s⋅t ⋅z - 1.125⋅s⋅t  + 12⋅s⋅t⋅z  + 6⋅s⋅t⋅z  - 72⋅s⋅t⋅z  - 60⋅
#
#
#
#      6             5               4             3              2
# s⋅t⋅z  + 91.5⋅s⋅t⋅z  + 123.75⋅s⋅t⋅z  + 61.5⋅s⋅t⋅z  + 17.25⋅s⋅t⋅z  - 0.328125⋅s
#
#
#
#                             13        12         11         10            9
# ⋅t⋅z - 0.2890625⋅s⋅t + 4⋅s⋅z   + 2⋅s⋅z   - 36⋅s⋅z   - 30⋅s⋅z   + 99.75⋅s⋅z  +
#
#
#
#            8           7             6                 5                 4
# 124.875⋅s⋅z  - 46.5⋅s⋅z  - 144.75⋅s⋅z  - 110.578125⋅s⋅z  - 45.9140625⋅s⋅z  - 3
#
#
#
#            3                2                                         4      3
# .265625⋅s⋅z  + 2.3203125⋅s⋅z  - 0.1748046875⋅s⋅z + 0.08056640625⋅s + t  + 4⋅t
#
#
#
#   4       3  2      3           3      2  8       2  6       2  5          2
# ⋅z  - 12⋅t ⋅z  - 4⋅t ⋅z - 0.75⋅t  + 6⋅t ⋅z  - 36⋅t ⋅z  - 12⋅t ⋅z  + 51.75⋅t ⋅z
#
#
#
# 4       2  3          2  2         2                2        12         10
#   + 36⋅t ⋅z  + 12.75⋅t ⋅z  + 2.25⋅t ⋅z - 1.2890625⋅t  + 4⋅t⋅z   - 36⋅t⋅z   - 1
#
#
#
#      9             8         7           6            5                4
# 2⋅t⋅z  + 105.75⋅t⋅z  + 72⋅t⋅z  - 82.5⋅t⋅z  - 103.5⋅t⋅z  - 58.828125⋅t⋅z  - 17.
#
#
#
#      3               2                                    16       14      13
# 5⋅t⋅z  + 5.484375⋅t⋅z  + 2.578125⋅t⋅z + 0.5361328125⋅t + z   - 12⋅z   - 4⋅z
#
#
#
#          12       11          10           9               8         7
# + 53.25⋅z   + 36⋅z   - 95.25⋅z   - 105.75⋅z  + 23.4609375⋅z  + 90.5⋅z  + 79.73
#
#
#
#       6              5                 4             3                 2
# 4375⋅z  + 34.828125⋅z  - 4.3154296875⋅z  - 6.984375⋅z  + 0.1025390625⋅z  + 0.4
#
#
#
#
# 638671875⋅z - 0.0514984130859375

# %%
from sympy import Symbol, solve, pprint
y=Symbol("y")
Photon_Sphere = 2*y**4 - 6*y**3 + 4*q*y**2 + 5*s*y + 6*t 

Photon_Sphere_Substituted = expand(Photon_Sphere.subs(y,z2+(3/4)) )

collect(Photon_Sphere_Substituted, z2)
# Out:
#         4  8           4  7            4  6            4  5            4  4
# 131072⋅q ⋅z  + 786432⋅q ⋅z  + 2064384⋅q ⋅z  + 3096576⋅q ⋅z  + 2903040⋅q ⋅z  +
#
#          4  3           4  2           4            4           3    7
# 1741824⋅q ⋅z  + 653184⋅q ⋅z  + 139968⋅q ⋅z + 13122⋅q  + 655360⋅q ⋅s⋅z  + 34406
#
#     3    6            3    5            3    4            3    3            3
# 40⋅q ⋅s⋅z  + 7741440⋅q ⋅s⋅z  + 9676800⋅q ⋅s⋅z  + 7257600⋅q ⋅s⋅z  + 3265920⋅q ⋅
#
#    2           3              3            3    6           3    5           3
# s⋅z  + 816480⋅q ⋅s⋅z + 87480⋅q ⋅s + 98304⋅q ⋅t⋅z  + 442368⋅q ⋅t⋅z  + 829440⋅q
#
#     4           3    3           3    2           3              3
# ⋅t⋅z  + 829440⋅q ⋅t⋅z  + 466560⋅q ⋅t⋅z  + 139968⋅q ⋅t⋅z + 17496⋅q ⋅t + 32768⋅q
#
# 3  10           3  9           3  8            3  7             3  6
#  ⋅z   + 147456⋅q ⋅z  - 608256⋅q ⋅z  - 4589568⋅q ⋅z  - 11321856⋅q ⋅z  - 1502323
#
#      3  5               3  4              3  3              3  2
# 2.0⋅q ⋅z  - 11919584.0⋅q ⋅z  - 5718120.0⋅q ⋅z  - 1561342.5⋅q ⋅z  - 200022.75⋅q
#
# 3                 3            2  2  6            2  2  5             2  2  4
#  ⋅z - 5211.84375⋅q  + 1228800⋅q ⋅s ⋅z  + 5529600⋅q ⋅s ⋅z  + 10368000⋅q ⋅s ⋅z
#
#             2  2  3            2  2  2            2  2             2  2
# + 10368000⋅q ⋅s ⋅z  + 5832000⋅q ⋅s ⋅z  + 1749600⋅q ⋅s ⋅z + 218700⋅q ⋅s  + 3686
#
#     2      5            2      4            2      3            2      2
# 40⋅q ⋅s⋅t⋅z  + 1382400⋅q ⋅s⋅t⋅z  + 2073600⋅q ⋅s⋅t⋅z  + 1555200⋅q ⋅s⋅t⋅z  + 583
#
#      2                2               2    9           2    8            2
# 200⋅q ⋅s⋅t⋅z + 87480⋅q ⋅s⋅t + 122880⋅q ⋅s⋅z  + 460800⋅q ⋅s⋅z  - 2626560⋅q ⋅s⋅z
#
# 7             2    6               2    5               2    4               2
#   - 15240960⋅q ⋅s⋅z  - 31026240.0⋅q ⋅s⋅z  - 33067440.0⋅q ⋅s⋅z  - 19899140.0⋅q
#
#     3              2    2               2                    2            2  2
# ⋅s⋅z  - 6522435.0⋅q ⋅s⋅z  - 967528.125⋅q ⋅s⋅z - 26599.21875⋅q ⋅s + 27648⋅q ⋅t
#
#   4          2  2  3          2  2  2          2  2           2  2          2
# ⋅z  + 82944⋅q ⋅t ⋅z  + 93312⋅q ⋅t ⋅z  + 46656⋅q ⋅t ⋅z + 8748⋅q ⋅t  + 18432⋅q ⋅
#
#    8          2    7           2    6            2    5              2    4
# t⋅z  + 55296⋅q ⋅t⋅z  - 435456⋅q ⋅t⋅z  - 1959552⋅q ⋅t⋅z  - 3184272.0⋅q ⋅t⋅z  -
#
#            2    3              2    2             2                   2
# 2571912.0⋅q ⋅t⋅z  - 1055937.0⋅q ⋅t⋅z  - 186412.5⋅q ⋅t⋅z - 5319.84375⋅q ⋅t + 30
#
#     2  12         2  11           2  10           2  9              2  8
# 72⋅q ⋅z   + 9216⋅q ⋅z   - 155520⋅q ⋅z   - 658368⋅q ⋅z  + 1177092.0⋅q ⋅z  + 103
#
#          2  7               2  6               2  5                    2  4
# 40136.0⋅q ⋅z  + 23040173.0⋅q ⋅z  + 26181862.5⋅q ⋅z  + 16824775.640625⋅q ⋅z  +
#
#                 2  3                     2  2                     2
# 5987953.265625⋅q ⋅z  + 1020487.33007813⋅q ⋅z  + 49595.2119140625⋅q ⋅z + 314.69
#
#             2              3  5              3  4              3  3
# 4030761719⋅q  + 1024000⋅q⋅s ⋅z  + 3840000⋅q⋅s ⋅z  + 5760000⋅q⋅s ⋅z  + 4320000⋅
#
#    3  2              3               3             2    4              2    3
# q⋅s ⋅z  + 1620000⋅q⋅s ⋅z + 243000⋅q⋅s  + 460800⋅q⋅s ⋅t⋅z  + 1382400⋅q⋅s ⋅t⋅z
#
#              2    2             2                 2               2  8
# + 1555200⋅q⋅s ⋅t⋅z  + 777600⋅q⋅s ⋅t⋅z + 145800⋅q⋅s ⋅t + 153600⋅q⋅s ⋅z  + 46080
#
#      2  7              2  6               2  5                 2  4
# 0⋅q⋅s ⋅z  - 3628800⋅q⋅s ⋅z  - 16329600⋅q⋅s ⋅z  - 26535600.0⋅q⋅s ⋅z  - 21432600
#
#       2  3                2  2                2                    2
# .0⋅q⋅s ⋅z  - 8801075.0⋅q⋅s ⋅z  - 1555837.5⋅q⋅s ⋅z - 45232.03125⋅q⋅s  + 69120⋅q
#
#     2  3               2  2               2                2                7
# ⋅s⋅t ⋅z  + 155520⋅q⋅s⋅t ⋅z  + 116640⋅q⋅s⋅t ⋅z + 29160⋅q⋅s⋅t  + 46080⋅q⋅s⋅t⋅z
#
#                 6                  5                  4                    3
# + 103680⋅q⋅s⋅t⋅z  - 1166400⋅q⋅s⋅t⋅z  - 4024080⋅q⋅s⋅t⋅z  - 4942620.0⋅q⋅s⋅t⋅z  -
#
#                   2                                                    11
#  2722815.0⋅q⋅s⋅t⋅z  - 598211.25⋅q⋅s⋅t⋅z - 18092.8125⋅q⋅s⋅t + 7680⋅q⋅s⋅z   + 17
#
#          10               9                8                  7
# 280⋅q⋅s⋅z   - 401760⋅q⋅s⋅z  - 1344600⋅q⋅s⋅z  + 3951180.0⋅q⋅s⋅z  + 22886955.0⋅q
#
#     6                    5                      4                         3
# ⋅s⋅z  + 40435056.25⋅q⋅s⋅z  + 35128124.0625⋅q⋅s⋅z  + 15720076.0546875⋅q⋅s⋅z  +
#
#                       2
# 3190706.12304688⋅q⋅s⋅z  + 167310.607910156⋅q⋅s⋅z + 1117.88635253906⋅q⋅s + 3456
#
#     3  2           3             3           2  6           2  5            2
# ⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z + 1944⋅q⋅t  + 3456⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z  - 91368⋅q⋅t ⋅
#
#  4             2  3               2  2               2                   2
# z  - 233280⋅q⋅t ⋅z  - 195736.5⋅q⋅t ⋅z  - 57408.75⋅q⋅t ⋅z - 1809.28125⋅q⋅t  + 1
#
#          10             9              8               7                 6
# 152⋅q⋅t⋅z   + 1728⋅q⋅t⋅z  - 61560⋅q⋅t⋅z  - 155520⋅q⋅t⋅z  + 709317.0⋅q⋅t⋅z  + 2
#
#               5                     4                  3
# 901055.5⋅q⋅t⋅z  + 3889466.8125⋅q⋅t⋅z  + 2352118.5⋅q⋅t⋅z  + 593922.533203125⋅q⋅
#
#    2                                                          14          13
# t⋅z  + 33152.0185546875⋅q⋅t⋅z + 214.577270507813⋅q⋅t + 128⋅q⋅z   + 192⋅q⋅z   -
#
#           12            11               10                9
#  10296⋅q⋅z   - 25920⋅q⋅z   + 258187.5⋅q⋅z   + 973397.25⋅q⋅z  - 1222734.03125⋅q
#
#   8                 7                       6                       5
# ⋅z  - 10553368.5⋅q⋅z  - 20380602.3222656⋅q⋅z  - 19027331.0771484⋅q⋅z  - 924353
#
#               4                       3                       2
# 5.99182129⋅q⋅z  - 2117634.65332031⋅q⋅z  - 153760.023399353⋅q⋅z  - 1949.8587684
#
#                                        4  4           4  3            4  2
# 6313⋅q⋅z - 6.8399977684021⋅q + 320000⋅s ⋅z  + 960000⋅s ⋅z  + 1080000⋅s ⋅z  + 5
#
#        4             4           3    3           3    2           3
# 40000⋅s ⋅z + 101250⋅s  + 192000⋅s ⋅t⋅z  + 432000⋅s ⋅t⋅z  + 324000⋅s ⋅t⋅z + 810
#
#     3            3  7           3  6            3  5            3  4
# 00⋅s ⋅t + 64000⋅s ⋅z  + 144000⋅s ⋅z  - 1620000⋅s ⋅z  - 5589000⋅s ⋅z  - 6864750
#
#     3  3              3  2               3                  3          2  2  2
# .0⋅s ⋅z  - 3781687.5⋅s ⋅z  - 831515.625⋅s ⋅z - 25628.90625⋅s  + 43200⋅s ⋅t ⋅z
#
#           2  2            2  2          2    6          2    5           2
#  + 64800⋅s ⋅t ⋅z + 24300⋅s ⋅t  + 28800⋅s ⋅t⋅z  + 43200⋅s ⋅t⋅z  - 761400⋅s ⋅t⋅z
#
# 4            2    3              2    2              2                    2
#   - 1944000⋅s ⋅t⋅z  - 1631137.5⋅s ⋅t⋅z  - 478406.25⋅s ⋅t⋅z - 15377.34375⋅s ⋅t
#
#         2  10         2  9           2  8           2  7              2  6
# + 4800⋅s ⋅z   + 7200⋅s ⋅z  - 256500⋅s ⋅z  - 648000⋅s ⋅z  + 2955487.5⋅s ⋅z  + 1
#
#             2  5                   2  4               2  3
# 2087731.25⋅s ⋅z  + 16206011.71875⋅s ⋅z  + 9800493.75⋅s ⋅z  + 2477377.22167969⋅
#
#  2  2                     2                       2           3             3
# s ⋅z  + 140933.410644531⋅s ⋅z + 988.993835449219⋅s  + 4320⋅s⋅t ⋅z + 3240⋅s⋅t
#
#           2  5           2  4             2  3             2  2
# + 4320⋅s⋅t ⋅z  + 3240⋅s⋅t ⋅z  - 116640⋅s⋅t ⋅z  - 204120⋅s⋅t ⋅z  - 91580.625⋅s⋅
#
#  2                   2             9             8              7
# t ⋅z - 3075.46875⋅s⋅t  + 1440⋅s⋅t⋅z  + 1080⋅s⋅t⋅z  - 77760⋅s⋅t⋅z  - 136080⋅s⋅t
#
#   6                  5                     4                   3
# ⋅z  + 988706.25⋅s⋅t⋅z  + 2884789.6875⋅s⋅t⋅z  + 2698211.25⋅s⋅t⋅z  + 916489.6875
#
#       2                                                          13          1
# ⋅s⋅t⋅z  + 55845.9008789063⋅s⋅t⋅z + 380.597534179688⋅s⋅t + 160⋅s⋅z   + 120⋅s⋅z
#
# 2            11            10                 9                   8
#   - 12960⋅s⋅z   - 22680⋅s⋅z   + 339744.375⋅s⋅z  + 961938.28125⋅s⋅z  - 2249876.
#
#       7                    6                      5                       4
# 25⋅s⋅z  - 11504303.4375⋅s⋅z  - 16847255.324707⋅s⋅z  - 11148447.3529053⋅s⋅z  -
#
#                     3                       2
# 3196723.73291016⋅s⋅z  - 256925.516967773⋅s⋅z  - 3440.93058586121⋅s⋅z - 12.6606
#
#                    4        3  4         3  2         3                3
# 774330139⋅s + 162⋅t  + 216⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z - 205.03125⋅t  + 108
#
#   2  8         2  6         2  5                2  4           2  3
# ⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z  + 78526.96875⋅t ⋅z  + 157464⋅t ⋅z  + 84267.84
#
#      2  2               2                       2         12           10
# 375⋅t ⋅z  + 5535.84375⋅t ⋅z + 36.5597534179688⋅t  + 24⋅t⋅z   - 1944⋅t⋅z   - 19
#
#       9                  8             7                  6
# 44⋅t⋅z  + 52419.65625⋅t⋅z  + 104976⋅t⋅z  - 416213.4375⋅t⋅z  - 1413485.4375⋅t⋅z
#
# 5                       4                  3                       2
#   - 1466974.22058105⋅t⋅z  - 572037.1875⋅t⋅z  - 50480.6693115234⋅t⋅z  - 658.075
#
#                                         16        14        13               1
# 561523438⋅t⋅z + 3.66708326339722⋅t + 2⋅z   - 216⋅z   - 216⋅z   + 8740.40625⋅z
#
# 2          11                 10                 9                     8
#   + 17496⋅z   - 148100.90625⋅z   - 471776.90625⋅z  + 573886.530944824⋅z  + 406
#
#            7                     6                     5                     4
# 0848.9375⋅z  + 6509932.89147949⋅z  + 4699711.98522949⋅z  + 1514245.90613794⋅z
#
#                      3                     2
#  + 155390.461303711⋅z  + 2982.33627748489⋅z  + 20.996250629425⋅z + 0.050589986
#
#
# 6111576

# %%
eq1 = x**2*(q-(3/2)) + x*(q+s-1) + (s*(1/2) + q*(1/4) + t - (3/16))

eq2 = Photon_Sphere_Substituted.subs(z2,0)

#result = solve([],[])

#eq2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 eq1 = x**2*(q-(3/2)) + x*(q+s-1) + (s*(1/2) + q*(1/4) + t - (3/16))
#       3 eq2 = Photon_Sphere_Substituted.subs(z2,0)
#       5 #result = solve([],[])
#       6
#       7 #eq2
#
# NameError: name 'x' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sympy import*
init_printing(use_unicode=True)
import fractions
import math

# %%
from sympy import symbols,Symbol,solve
q,s,t,r = symbols("q,s,t,r")
g_tt = 1 + (2/r) + (q/r**2) + (s/r**3) + (t/r**4)
Horizon_Equation = g_tt.subs({q:3/2,s:1/2,t:9/16})
horizons = solve(Horizon_Equation)
h1 = []
for horizon in horizons:
    hr = horizon
    if hr.is_positive and hr.is_real:
        print(hr)
        h1.append(hr)
        
if len(h1)>0:       
    z = max(h1)
    print(z)

# %%
z=symbols("z")

# Horizon equation
z1 = z**4 + (q-3/2)*(z**2) +(q+s-1)*z + ((q/4) + (s/2) + t - (3/16))

#Photon Sphere Equation
z2 = z**4 + (2*q-(27/8))*(z**2) + (3*q + (5/2)*s - (27/8))*z + ((9/8)*q + (15/8)*s + 3*t- (243/256))

# %%
z1
# Out:
# q   s        4    2
# ─ + ─ + t + z  + z ⋅(2⋅q - 3) + z⋅(q + s - 1) - 0.1875
# 4   2

# %%
z2
# Out:
#                     4    2
# 9⋅q + 15⋅s + 3⋅t + z  + z ⋅(16⋅q - 27) + z⋅(24⋅q + 20⋅s - 27) - 0.94921875

# %%
from sympy import*
Q,R,T,r = symbols("Q,R,T,R")
First_Energy_Condition = Q*(r**2) + 2*r*R + 3*T

Roots_First_Energy_Condition = solve (First_Energy_Condition,r)

Roots_First_Energy_Condition
# Out:
# ⎡        _______         _______⎤
# ⎢       ╱  -T           ╱  -T   ⎥
# ⎢-√3⋅  ╱  ───── , √3⋅  ╱  ───── ⎥
# ⎣    ╲╱   Q + 2      ╲╱   Q + 2 ⎦

# %%
Third_Energy_Condition = 2*Q*r**2 + 5*r*R + 9*T

Roots_Third_Energy_Condition = solveset (Eq(Third_Energy_Condition,0),r)

Roots_Third_Energy_Condition
# Out:
# ⎧       _________        _________⎫
# ⎪      ╱   -T           ╱   -T    ⎪
# ⎨-3⋅  ╱  ─────── , 3⋅  ╱  ─────── ⎬
# ⎪   ╲╱   2⋅Q + 5     ╲╱   2⋅Q + 5 ⎪
# ⎩                                 ⎭

# %%
Horizon = x**4 - 2*x**3 + q*x**2 + s*x + t 

Horizon_Substituted = expand(Horizon.subs(x,z1+(1/2))) 

collect(Horizon_Substituted,z1)
# Out:
#                                                 4  4      4  3    4  2    4
#     4  8       4  7       4  6       4  5   17⋅q ⋅z    5⋅q ⋅z    q ⋅z    q ⋅z
# 16⋅q ⋅z  + 32⋅q ⋅z  + 32⋅q ⋅z  + 20⋅q ⋅z  + ──────── + ─────── + ───── + ────
#                                                2          2        2      16
#
#     4                                                           3    3
#    q        3    7       3    6       3    5       3    4   25⋅q ⋅s⋅z       3
# + ─── + 32⋅q ⋅s⋅z  + 64⋅q ⋅s⋅z  + 60⋅q ⋅s⋅z  + 34⋅q ⋅s⋅z  + ────────── + 3⋅q ⋅
#   256                                                           2
#
#           3        3
#    2   7⋅q ⋅s⋅z   q ⋅s       3    6       3    5       3    4       3    3   9
# s⋅z  + ──────── + ──── + 32⋅q ⋅t⋅z  + 48⋅q ⋅t⋅z  + 36⋅q ⋅t⋅z  + 16⋅q ⋅t⋅z  + ─
#           16       32
#
#   3    2      3        3
# ⋅q ⋅t⋅z    3⋅q ⋅t⋅z   q ⋅t       3  10       3  9       3  8        3  7
# ──────── + ──────── + ──── + 32⋅q ⋅z   + 48⋅q ⋅z  - 60⋅q ⋅z  - 160⋅q ⋅z  - 157
#    2          4        16
#
#
#     3  6          3  5            3  4         3  3            3  2
# .5⋅q ⋅z  - 92.25⋅q ⋅z  - 32.1875⋅q ⋅z  - 5.75⋅q ⋅z  + 0.21875⋅q ⋅z  + 0.296875
#
#
#
#   3                 3       2  2  6       2  2  5       2  2  4       2  2  3
# ⋅q ⋅z + 0.05078125⋅q  + 24⋅q ⋅s ⋅z  + 48⋅q ⋅s ⋅z  + 42⋅q ⋅s ⋅z  + 21⋅q ⋅s ⋅z
#
#
#       2  2  2      2  2        2  2
#   51⋅q ⋅s ⋅z    9⋅q ⋅s ⋅z   3⋅q ⋅s        2      5       2      4       2
# + ─────────── + ───────── + ─────── + 48⋅q ⋅s⋅t⋅z  + 72⋅q ⋅s⋅t⋅z  + 48⋅q ⋅s⋅t⋅
#        8            8          32
#
#                         2            2
#  3       2      2   15⋅q ⋅s⋅t⋅z   3⋅q ⋅s⋅t       2    9       2    8       2
# z  + 18⋅q ⋅s⋅t⋅z  + ─────────── + ──────── + 48⋅q ⋅s⋅z  + 72⋅q ⋅s⋅z  - 96⋅q ⋅s
#                          4           8
#
#
#   7        2    6           2    5            2    4          2    3         2
# ⋅z  - 246⋅q ⋅s⋅z  - 221.25⋅q ⋅s⋅z  - 115.125⋅q ⋅s⋅z  - 34.25⋅q ⋅s⋅z  - 4.25⋅q
#
#
#
#     2             2                  2         2  2  4       2  2  3       2
# ⋅s⋅z  + 0.421875⋅q ⋅s⋅z + 0.1796875⋅q ⋅s + 24⋅q ⋅t ⋅z  + 24⋅q ⋅t ⋅z  + 12⋅q ⋅t
#
#
#                       2  2
# 2  2      2  2     3⋅q ⋅t        2    8       2    7        2    6        2
#  ⋅z  + 3⋅q ⋅t ⋅z + ─────── + 48⋅q ⋅t⋅z  + 48⋅q ⋅t⋅z  - 120⋅q ⋅t⋅z  - 186⋅q ⋅t⋅
#                       8
#
#
#  5           2    4         2    3         2    2          2                 2
# z  - 128.25⋅q ⋅t⋅z  - 51.0⋅q ⋅t⋅z  - 8.75⋅q ⋅t⋅z  + 0.125⋅q ⋅t⋅z + 0.359375⋅q
#
#
#
#          2  12       2  11        2  10        2  9           2  8          2
# ⋅t + 24⋅q ⋅z   + 24⋅q ⋅z   - 132⋅q ⋅z   - 189⋅q ⋅z  + 87.375⋅q ⋅z  + 309.0⋅q ⋅
#
#
#
#  7           2  6            2  5              2  4            2  3
# z  + 294.25⋅q ⋅z  + 159.125⋅q ⋅z  + 39.078125⋅q ⋅z  - 2.03125⋅q ⋅z  - 2.90625⋅
#
#
#
#  2  2               2                    2        3  5         3  4         3
# q ⋅z  - 0.37890625⋅q ⋅z + 0.07568359375⋅q  + 8⋅q⋅s ⋅z  + 16⋅q⋅s ⋅z  + 13⋅q⋅s ⋅
#
#
#            3  2        3        3
#  3   11⋅q⋅s ⋅z    5⋅q⋅s ⋅z   q⋅s          2    4         2    3         2    2
# z  + ────────── + ──────── + ──── + 24⋅q⋅s ⋅t⋅z  + 36⋅q⋅s ⋅t⋅z  + 21⋅q⋅s ⋅t⋅z
#          2           4        8
#
#                      2
#         2       3⋅q⋅s ⋅t         2  8         2  7         2  6          2  5
#  + 6⋅q⋅s ⋅t⋅z + ──────── + 24⋅q⋅s ⋅z  + 36⋅q⋅s ⋅z  - 51⋅q⋅s ⋅z  - 126⋅q⋅s ⋅z
#                    4
#
#
#             2  4            2  3              2  2            2
# - 102.75⋅q⋅s ⋅z  - 45.75⋅q⋅s ⋅z  - 11.1875⋅q⋅s ⋅z  - 0.875⋅q⋅s ⋅z + 0.109375⋅q
#
#
#                                                         2
#   2           2  3           2  2          2     3⋅q⋅s⋅t              7
# ⋅s  + 24⋅q⋅s⋅t ⋅z  + 24⋅q⋅s⋅t ⋅z  + 9⋅q⋅s⋅t ⋅z + ──────── + 48⋅q⋅s⋅t⋅z  + 48⋅q
#                                                     2
#
#
#       6              5              4                3               2
# ⋅s⋅t⋅z  - 126⋅q⋅s⋅t⋅z  - 189⋅q⋅s⋅t⋅z  - 111.0⋅q⋅s⋅t⋅z  - 36.0⋅q⋅s⋅t⋅z  - 4.375
#
#
#                                                                           8
#                                   11           10            9   381⋅q⋅s⋅z
# ⋅q⋅s⋅t⋅z + 0.4375⋅q⋅s⋅t + 24⋅q⋅s⋅z   + 24⋅q⋅s⋅z   - 135⋅q⋅s⋅z  - ────────── +
#                                                                      2
#
#
#            7              6                5                 4
# 105.0⋅q⋅s⋅z  + 324.0⋅q⋅s⋅z  + 271.625⋅q⋅s⋅z  + 127.9375⋅q⋅s⋅z  + 25.96875⋅q⋅s⋅
#
#
#
#  3                2                                             3  2        3
# z  - 1.59375⋅q⋅s⋅z  - 0.74609375⋅q⋅s⋅z + 0.240234375⋅q⋅s + 8⋅q⋅t ⋅z  + 4⋅q⋅t ⋅
#
#
#
#        3         2  6         2  5         2  4         2  3           2  2
# z + q⋅t  + 24⋅q⋅t ⋅z  + 12⋅q⋅t ⋅z  - 69⋅q⋅t ⋅z  - 60⋅q⋅t ⋅z  - 25.5⋅q⋅t ⋅z  -
#
#
#
#         2               2           10           9            8            7
# 5.25⋅q⋅t ⋅z + 0.4375⋅q⋅t  + 24⋅q⋅t⋅z   + 12⋅q⋅t⋅z  - 141⋅q⋅t⋅z  - 120⋅q⋅t⋅z  +
#
#
#
#             6              5                4             3                2
#  165.0⋅q⋅t⋅z  + 241.5⋅q⋅t⋅z  + 150.875⋅q⋅t⋅z  + 52.5⋅q⋅t⋅z  - 0.28125⋅q⋅t⋅z  -
#
#
#
#                                         14        13         12         11
#  3.453125⋅q⋅t⋅z - 0.01953125⋅q⋅t + 8⋅q⋅z   + 4⋅q⋅z   - 71⋅q⋅z   - 60⋅q⋅z   + 1
#
#
#
#         10             9              8            7                6
# 90.5⋅q⋅z   + 246.75⋅q⋅z  - 65.5625⋅q⋅z  - 271.5⋅q⋅z  - 247.78125⋅q⋅z  - 121.70
#
#
#
#         5                  4                3                  2
# 3125⋅q⋅z  - 11.61328125⋅q⋅z  + 12.265625⋅q⋅z  + 2.146484375⋅q⋅z  - 0.444335937
#
#
#                                                 4  2    4      4
#                             4  4      4  3   3⋅s ⋅z    s ⋅z   s       3    3
# 5⋅q⋅z - 0.018310546875⋅q + s ⋅z  + 2⋅s ⋅z  + ─────── + ──── + ── + 4⋅s ⋅t⋅z  +
#                                                 2       2     16
#
#                          3                                       3  4
#     3    2      3       s ⋅t      3  7      3  6      3  5   43⋅s ⋅z
#  6⋅s ⋅t⋅z  + 3⋅s ⋅t⋅z + ──── + 4⋅s ⋅z  + 6⋅s ⋅z  - 9⋅s ⋅z  - ──────── - 15.75⋅
#                          2                                      2
#
#                                                                              2
#  3  3          3  2           3              3      2  2  2      2  2     3⋅s
# s ⋅z  - 5.625⋅s ⋅z  - 1.0625⋅s ⋅z - 0.09375⋅s  + 6⋅s ⋅t ⋅z  + 6⋅s ⋅t ⋅z + ────
#                                                                              2
#
#   2
# ⋅t        2    6       2    5       2    4       2    3          2    2
# ─── + 12⋅s ⋅t⋅z  + 12⋅s ⋅t⋅z  - 33⋅s ⋅t⋅z  - 48⋅s ⋅t⋅z  - 23.25⋅s ⋅t⋅z  - 5.25
#
#
#                                                  2  8
#   2               2        2  10      2  9   69⋅s ⋅z        2  7          2  6
# ⋅s ⋅t⋅z - 0.5625⋅s ⋅t + 6⋅s ⋅z   + 6⋅s ⋅z  - ──────── - 48⋅s ⋅z  + 30.75⋅s ⋅z
#                                                 2
#
#
#           2  5            2  4         2  3              2  2              2
#  + 84.75⋅s ⋅z  + 61.6875⋅s ⋅z  + 24.0⋅s ⋅z  + 4.1484375⋅s ⋅z  + 0.2734375⋅s ⋅z
#
#
#
#                 2        3          3         2  5        2  4         2  3
#  + 0.177734375⋅s  + 4⋅s⋅t ⋅z + 2⋅s⋅t  + 12⋅s⋅t ⋅z  + 6⋅s⋅t ⋅z  - 36⋅s⋅t ⋅z  -
#
#
#
#       2  2           2              2           9          8           7
# 30⋅s⋅t ⋅z  - 8.25⋅s⋅t ⋅z - 1.125⋅s⋅t  + 12⋅s⋅t⋅z  + 6⋅s⋅t⋅z  - 72⋅s⋅t⋅z  - 60⋅
#
#
#
#      6             5               4             3              2
# s⋅t⋅z  + 91.5⋅s⋅t⋅z  + 123.75⋅s⋅t⋅z  + 61.5⋅s⋅t⋅z  + 17.25⋅s⋅t⋅z  - 0.328125⋅s
#
#
#
#                             13        12         11         10            9
# ⋅t⋅z - 0.2890625⋅s⋅t + 4⋅s⋅z   + 2⋅s⋅z   - 36⋅s⋅z   - 30⋅s⋅z   + 99.75⋅s⋅z  +
#
#
#
#            8           7             6                 5                 4
# 124.875⋅s⋅z  - 46.5⋅s⋅z  - 144.75⋅s⋅z  - 110.578125⋅s⋅z  - 45.9140625⋅s⋅z  - 3
#
#
#
#            3                2                                         4      3
# .265625⋅s⋅z  + 2.3203125⋅s⋅z  - 0.1748046875⋅s⋅z + 0.08056640625⋅s + t  + 4⋅t
#
#
#
#   4       3  2      3           3      2  8       2  6       2  5          2
# ⋅z  - 12⋅t ⋅z  - 4⋅t ⋅z - 0.75⋅t  + 6⋅t ⋅z  - 36⋅t ⋅z  - 12⋅t ⋅z  + 51.75⋅t ⋅z
#
#
#
# 4       2  3          2  2         2                2        12         10
#   + 36⋅t ⋅z  + 12.75⋅t ⋅z  + 2.25⋅t ⋅z - 1.2890625⋅t  + 4⋅t⋅z   - 36⋅t⋅z   - 1
#
#
#
#      9             8         7           6            5                4
# 2⋅t⋅z  + 105.75⋅t⋅z  + 72⋅t⋅z  - 82.5⋅t⋅z  - 103.5⋅t⋅z  - 58.828125⋅t⋅z  - 17.
#
#
#
#      3               2                                    16       14      13
# 5⋅t⋅z  + 5.484375⋅t⋅z  + 2.578125⋅t⋅z + 0.5361328125⋅t + z   - 12⋅z   - 4⋅z
#
#
#
#          12       11          10           9               8         7
# + 53.25⋅z   + 36⋅z   - 95.25⋅z   - 105.75⋅z  + 23.4609375⋅z  + 90.5⋅z  + 79.73
#
#
#
#       6              5                 4             3                 2
# 4375⋅z  + 34.828125⋅z  - 4.3154296875⋅z  - 6.984375⋅z  + 0.1025390625⋅z  + 0.4
#
#
#
#
# 638671875⋅z - 0.0514984130859375

# %%
Photon_Sphere = 2*y**4 - 6*y**3 + 4*q*y**2 + 5*s*y + 6*t 

Photon_Sphere_Substituted = expand(Photon_Sphere.subs(y,z2+(3/4)))

collect(Photon_Sphere_Substituted,z2)
# Out:
#         4  8           4  7            4  6            4  5            4  4
# 131072⋅q ⋅z  + 786432⋅q ⋅z  + 2064384⋅q ⋅z  + 3096576⋅q ⋅z  + 2903040⋅q ⋅z  +
#
#          4  3           4  2           4            4           3    7
# 1741824⋅q ⋅z  + 653184⋅q ⋅z  + 139968⋅q ⋅z + 13122⋅q  + 655360⋅q ⋅s⋅z  + 34406
#
#     3    6            3    5            3    4            3    3            3
# 40⋅q ⋅s⋅z  + 7741440⋅q ⋅s⋅z  + 9676800⋅q ⋅s⋅z  + 7257600⋅q ⋅s⋅z  + 3265920⋅q ⋅
#
#    2           3              3            3    6           3    5           3
# s⋅z  + 816480⋅q ⋅s⋅z + 87480⋅q ⋅s + 98304⋅q ⋅t⋅z  + 442368⋅q ⋅t⋅z  + 829440⋅q
#
#     4           3    3           3    2           3              3
# ⋅t⋅z  + 829440⋅q ⋅t⋅z  + 466560⋅q ⋅t⋅z  + 139968⋅q ⋅t⋅z + 17496⋅q ⋅t + 32768⋅q
#
# 3  10           3  9           3  8            3  7             3  6
#  ⋅z   + 147456⋅q ⋅z  - 608256⋅q ⋅z  - 4589568⋅q ⋅z  - 11321856⋅q ⋅z  - 1502323
#
#      3  5               3  4              3  3              3  2
# 2.0⋅q ⋅z  - 11919584.0⋅q ⋅z  - 5718120.0⋅q ⋅z  - 1561342.5⋅q ⋅z  - 200022.75⋅q
#
# 3                 3            2  2  6            2  2  5             2  2  4
#  ⋅z - 5211.84375⋅q  + 1228800⋅q ⋅s ⋅z  + 5529600⋅q ⋅s ⋅z  + 10368000⋅q ⋅s ⋅z
#
#             2  2  3            2  2  2            2  2             2  2
# + 10368000⋅q ⋅s ⋅z  + 5832000⋅q ⋅s ⋅z  + 1749600⋅q ⋅s ⋅z + 218700⋅q ⋅s  + 3686
#
#     2      5            2      4            2      3            2      2
# 40⋅q ⋅s⋅t⋅z  + 1382400⋅q ⋅s⋅t⋅z  + 2073600⋅q ⋅s⋅t⋅z  + 1555200⋅q ⋅s⋅t⋅z  + 583
#
#      2                2               2    9           2    8            2
# 200⋅q ⋅s⋅t⋅z + 87480⋅q ⋅s⋅t + 122880⋅q ⋅s⋅z  + 460800⋅q ⋅s⋅z  - 2626560⋅q ⋅s⋅z
#
# 7             2    6               2    5               2    4               2
#   - 15240960⋅q ⋅s⋅z  - 31026240.0⋅q ⋅s⋅z  - 33067440.0⋅q ⋅s⋅z  - 19899140.0⋅q
#
#     3              2    2               2                    2            2  2
# ⋅s⋅z  - 6522435.0⋅q ⋅s⋅z  - 967528.125⋅q ⋅s⋅z - 26599.21875⋅q ⋅s + 27648⋅q ⋅t
#
#   4          2  2  3          2  2  2          2  2           2  2          2
# ⋅z  + 82944⋅q ⋅t ⋅z  + 93312⋅q ⋅t ⋅z  + 46656⋅q ⋅t ⋅z + 8748⋅q ⋅t  + 18432⋅q ⋅
#
#    8          2    7           2    6            2    5              2    4
# t⋅z  + 55296⋅q ⋅t⋅z  - 435456⋅q ⋅t⋅z  - 1959552⋅q ⋅t⋅z  - 3184272.0⋅q ⋅t⋅z  -
#
#            2    3              2    2             2                   2
# 2571912.0⋅q ⋅t⋅z  - 1055937.0⋅q ⋅t⋅z  - 186412.5⋅q ⋅t⋅z - 5319.84375⋅q ⋅t + 30
#
#     2  12         2  11           2  10           2  9              2  8
# 72⋅q ⋅z   + 9216⋅q ⋅z   - 155520⋅q ⋅z   - 658368⋅q ⋅z  + 1177092.0⋅q ⋅z  + 103
#
#          2  7               2  6               2  5                    2  4
# 40136.0⋅q ⋅z  + 23040173.0⋅q ⋅z  + 26181862.5⋅q ⋅z  + 16824775.640625⋅q ⋅z  +
#
#                 2  3                     2  2                     2
# 5987953.265625⋅q ⋅z  + 1020487.33007813⋅q ⋅z  + 49595.2119140625⋅q ⋅z + 314.69
#
#             2              3  5              3  4              3  3
# 4030761719⋅q  + 1024000⋅q⋅s ⋅z  + 3840000⋅q⋅s ⋅z  + 5760000⋅q⋅s ⋅z  + 4320000⋅
#
#    3  2              3               3             2    4              2    3
# q⋅s ⋅z  + 1620000⋅q⋅s ⋅z + 243000⋅q⋅s  + 460800⋅q⋅s ⋅t⋅z  + 1382400⋅q⋅s ⋅t⋅z
#
#              2    2             2                 2               2  8
# + 1555200⋅q⋅s ⋅t⋅z  + 777600⋅q⋅s ⋅t⋅z + 145800⋅q⋅s ⋅t + 153600⋅q⋅s ⋅z  + 46080
#
#      2  7              2  6               2  5                 2  4
# 0⋅q⋅s ⋅z  - 3628800⋅q⋅s ⋅z  - 16329600⋅q⋅s ⋅z  - 26535600.0⋅q⋅s ⋅z  - 21432600
#
#       2  3                2  2                2                    2
# .0⋅q⋅s ⋅z  - 8801075.0⋅q⋅s ⋅z  - 1555837.5⋅q⋅s ⋅z - 45232.03125⋅q⋅s  + 69120⋅q
#
#     2  3               2  2               2                2                7
# ⋅s⋅t ⋅z  + 155520⋅q⋅s⋅t ⋅z  + 116640⋅q⋅s⋅t ⋅z + 29160⋅q⋅s⋅t  + 46080⋅q⋅s⋅t⋅z
#
#                 6                  5                  4                    3
# + 103680⋅q⋅s⋅t⋅z  - 1166400⋅q⋅s⋅t⋅z  - 4024080⋅q⋅s⋅t⋅z  - 4942620.0⋅q⋅s⋅t⋅z  -
#
#                   2                                                    11
#  2722815.0⋅q⋅s⋅t⋅z  - 598211.25⋅q⋅s⋅t⋅z - 18092.8125⋅q⋅s⋅t + 7680⋅q⋅s⋅z   + 17
#
#          10               9                8                  7
# 280⋅q⋅s⋅z   - 401760⋅q⋅s⋅z  - 1344600⋅q⋅s⋅z  + 3951180.0⋅q⋅s⋅z  + 22886955.0⋅q
#
#     6                    5                      4                         3
# ⋅s⋅z  + 40435056.25⋅q⋅s⋅z  + 35128124.0625⋅q⋅s⋅z  + 15720076.0546875⋅q⋅s⋅z  +
#
#                       2
# 3190706.12304688⋅q⋅s⋅z  + 167310.607910156⋅q⋅s⋅z + 1117.88635253906⋅q⋅s + 3456
#
#     3  2           3             3           2  6           2  5            2
# ⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z + 1944⋅q⋅t  + 3456⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z  - 91368⋅q⋅t ⋅
#
#  4             2  3               2  2               2                   2
# z  - 233280⋅q⋅t ⋅z  - 195736.5⋅q⋅t ⋅z  - 57408.75⋅q⋅t ⋅z - 1809.28125⋅q⋅t  + 1
#
#          10             9              8               7                 6
# 152⋅q⋅t⋅z   + 1728⋅q⋅t⋅z  - 61560⋅q⋅t⋅z  - 155520⋅q⋅t⋅z  + 709317.0⋅q⋅t⋅z  + 2
#
#               5                     4                  3
# 901055.5⋅q⋅t⋅z  + 3889466.8125⋅q⋅t⋅z  + 2352118.5⋅q⋅t⋅z  + 593922.533203125⋅q⋅
#
#    2                                                          14          13
# t⋅z  + 33152.0185546875⋅q⋅t⋅z + 214.577270507813⋅q⋅t + 128⋅q⋅z   + 192⋅q⋅z   -
#
#           12            11               10                9
#  10296⋅q⋅z   - 25920⋅q⋅z   + 258187.5⋅q⋅z   + 973397.25⋅q⋅z  - 1222734.03125⋅q
#
#   8                 7                       6                       5
# ⋅z  - 10553368.5⋅q⋅z  - 20380602.3222656⋅q⋅z  - 19027331.0771484⋅q⋅z  - 924353
#
#               4                       3                       2
# 5.99182129⋅q⋅z  - 2117634.65332031⋅q⋅z  - 153760.023399353⋅q⋅z  - 1949.8587684
#
#                                        4  4           4  3            4  2
# 6313⋅q⋅z - 6.8399977684021⋅q + 320000⋅s ⋅z  + 960000⋅s ⋅z  + 1080000⋅s ⋅z  + 5
#
#        4             4           3    3           3    2           3
# 40000⋅s ⋅z + 101250⋅s  + 192000⋅s ⋅t⋅z  + 432000⋅s ⋅t⋅z  + 324000⋅s ⋅t⋅z + 810
#
#     3            3  7           3  6            3  5            3  4
# 00⋅s ⋅t + 64000⋅s ⋅z  + 144000⋅s ⋅z  - 1620000⋅s ⋅z  - 5589000⋅s ⋅z  - 6864750
#
#     3  3              3  2               3                  3          2  2  2
# .0⋅s ⋅z  - 3781687.5⋅s ⋅z  - 831515.625⋅s ⋅z - 25628.90625⋅s  + 43200⋅s ⋅t ⋅z
#
#           2  2            2  2          2    6          2    5           2
#  + 64800⋅s ⋅t ⋅z + 24300⋅s ⋅t  + 28800⋅s ⋅t⋅z  + 43200⋅s ⋅t⋅z  - 761400⋅s ⋅t⋅z
#
# 4            2    3              2    2              2                    2
#   - 1944000⋅s ⋅t⋅z  - 1631137.5⋅s ⋅t⋅z  - 478406.25⋅s ⋅t⋅z - 15377.34375⋅s ⋅t
#
#         2  10         2  9           2  8           2  7              2  6
# + 4800⋅s ⋅z   + 7200⋅s ⋅z  - 256500⋅s ⋅z  - 648000⋅s ⋅z  + 2955487.5⋅s ⋅z  + 1
#
#             2  5                   2  4               2  3
# 2087731.25⋅s ⋅z  + 16206011.71875⋅s ⋅z  + 9800493.75⋅s ⋅z  + 2477377.22167969⋅
#
#  2  2                     2                       2           3             3
# s ⋅z  + 140933.410644531⋅s ⋅z + 988.993835449219⋅s  + 4320⋅s⋅t ⋅z + 3240⋅s⋅t
#
#           2  5           2  4             2  3             2  2
# + 4320⋅s⋅t ⋅z  + 3240⋅s⋅t ⋅z  - 116640⋅s⋅t ⋅z  - 204120⋅s⋅t ⋅z  - 91580.625⋅s⋅
#
#  2                   2             9             8              7
# t ⋅z - 3075.46875⋅s⋅t  + 1440⋅s⋅t⋅z  + 1080⋅s⋅t⋅z  - 77760⋅s⋅t⋅z  - 136080⋅s⋅t
#
#   6                  5                     4                   3
# ⋅z  + 988706.25⋅s⋅t⋅z  + 2884789.6875⋅s⋅t⋅z  + 2698211.25⋅s⋅t⋅z  + 916489.6875
#
#       2                                                          13          1
# ⋅s⋅t⋅z  + 55845.9008789063⋅s⋅t⋅z + 380.597534179688⋅s⋅t + 160⋅s⋅z   + 120⋅s⋅z
#
# 2            11            10                 9                   8
#   - 12960⋅s⋅z   - 22680⋅s⋅z   + 339744.375⋅s⋅z  + 961938.28125⋅s⋅z  - 2249876.
#
#       7                    6                      5                       4
# 25⋅s⋅z  - 11504303.4375⋅s⋅z  - 16847255.324707⋅s⋅z  - 11148447.3529053⋅s⋅z  -
#
#                     3                       2
# 3196723.73291016⋅s⋅z  - 256925.516967773⋅s⋅z  - 3440.93058586121⋅s⋅z - 12.6606
#
#                    4        3  4         3  2         3                3
# 774330139⋅s + 162⋅t  + 216⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z - 205.03125⋅t  + 108
#
#   2  8         2  6         2  5                2  4           2  3
# ⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z  + 78526.96875⋅t ⋅z  + 157464⋅t ⋅z  + 84267.84
#
#      2  2               2                       2         12           10
# 375⋅t ⋅z  + 5535.84375⋅t ⋅z + 36.5597534179688⋅t  + 24⋅t⋅z   - 1944⋅t⋅z   - 19
#
#       9                  8             7                  6
# 44⋅t⋅z  + 52419.65625⋅t⋅z  + 104976⋅t⋅z  - 416213.4375⋅t⋅z  - 1413485.4375⋅t⋅z
#
# 5                       4                  3                       2
#   - 1466974.22058105⋅t⋅z  - 572037.1875⋅t⋅z  - 50480.6693115234⋅t⋅z  - 658.075
#
#                                         16        14        13               1
# 561523438⋅t⋅z + 3.66708326339722⋅t + 2⋅z   - 216⋅z   - 216⋅z   + 8740.40625⋅z
#
# 2          11                 10                 9                     8
#   + 17496⋅z   - 148100.90625⋅z   - 471776.90625⋅z  + 573886.530944824⋅z  + 406
#
#            7                     6                     5                     4
# 0848.9375⋅z  + 6509932.89147949⋅z  + 4699711.98522949⋅z  + 1514245.90613794⋅z
#
#                      3                     2
#  + 155390.461303711⋅z  + 2982.33627748489⋅z  + 20.996250629425⋅z + 0.050589986
#
#
# 6111576

# %%
eq1 = x**2*(q-(3/2)) + x*(q+s-1) + (s*(1/2) + q*(1/4) + t - (3/16))

eq2 = Photon_Sphere_Substituted.subs(z2,0)
eq2
# Out:
#         4  8           4  7            4  6            4  5            4  4
# 131072⋅q ⋅z  + 786432⋅q ⋅z  + 2064384⋅q ⋅z  + 3096576⋅q ⋅z  + 2903040⋅q ⋅z  +
#
#          4  3           4  2           4            4           3    7
# 1741824⋅q ⋅z  + 653184⋅q ⋅z  + 139968⋅q ⋅z + 13122⋅q  + 655360⋅q ⋅s⋅z  + 34406
#
#     3    6            3    5            3    4            3    3            3
# 40⋅q ⋅s⋅z  + 7741440⋅q ⋅s⋅z  + 9676800⋅q ⋅s⋅z  + 7257600⋅q ⋅s⋅z  + 3265920⋅q ⋅
#
#    2           3              3            3    6           3    5           3
# s⋅z  + 816480⋅q ⋅s⋅z + 87480⋅q ⋅s + 98304⋅q ⋅t⋅z  + 442368⋅q ⋅t⋅z  + 829440⋅q
#
#     4           3    3           3    2           3              3
# ⋅t⋅z  + 829440⋅q ⋅t⋅z  + 466560⋅q ⋅t⋅z  + 139968⋅q ⋅t⋅z + 17496⋅q ⋅t + 32768⋅q
#
# 3  10           3  9           3  8            3  7             3  6
#  ⋅z   + 147456⋅q ⋅z  - 608256⋅q ⋅z  - 4589568⋅q ⋅z  - 11321856⋅q ⋅z  - 1502323
#
#      3  5               3  4              3  3              3  2
# 2.0⋅q ⋅z  - 11919584.0⋅q ⋅z  - 5718120.0⋅q ⋅z  - 1561342.5⋅q ⋅z  - 200022.75⋅q
#
# 3                 3            2  2  6            2  2  5             2  2  4
#  ⋅z - 5211.84375⋅q  + 1228800⋅q ⋅s ⋅z  + 5529600⋅q ⋅s ⋅z  + 10368000⋅q ⋅s ⋅z
#
#             2  2  3            2  2  2            2  2             2  2
# + 10368000⋅q ⋅s ⋅z  + 5832000⋅q ⋅s ⋅z  + 1749600⋅q ⋅s ⋅z + 218700⋅q ⋅s  + 3686
#
#     2      5            2      4            2      3            2      2
# 40⋅q ⋅s⋅t⋅z  + 1382400⋅q ⋅s⋅t⋅z  + 2073600⋅q ⋅s⋅t⋅z  + 1555200⋅q ⋅s⋅t⋅z  + 583
#
#      2                2               2    9           2    8            2
# 200⋅q ⋅s⋅t⋅z + 87480⋅q ⋅s⋅t + 122880⋅q ⋅s⋅z  + 460800⋅q ⋅s⋅z  - 2626560⋅q ⋅s⋅z
#
# 7             2    6               2    5               2    4               2
#   - 15240960⋅q ⋅s⋅z  - 31026240.0⋅q ⋅s⋅z  - 33067440.0⋅q ⋅s⋅z  - 19899140.0⋅q
#
#     3              2    2               2                    2            2  2
# ⋅s⋅z  - 6522435.0⋅q ⋅s⋅z  - 967528.125⋅q ⋅s⋅z - 26599.21875⋅q ⋅s + 27648⋅q ⋅t
#
#   4          2  2  3          2  2  2          2  2           2  2          2
# ⋅z  + 82944⋅q ⋅t ⋅z  + 93312⋅q ⋅t ⋅z  + 46656⋅q ⋅t ⋅z + 8748⋅q ⋅t  + 18432⋅q ⋅
#
#    8          2    7           2    6            2    5              2    4
# t⋅z  + 55296⋅q ⋅t⋅z  - 435456⋅q ⋅t⋅z  - 1959552⋅q ⋅t⋅z  - 3184272.0⋅q ⋅t⋅z  -
#
#            2    3              2    2             2                   2
# 2571912.0⋅q ⋅t⋅z  - 1055937.0⋅q ⋅t⋅z  - 186412.5⋅q ⋅t⋅z - 5319.84375⋅q ⋅t + 30
#
#     2  12         2  11           2  10           2  9              2  8
# 72⋅q ⋅z   + 9216⋅q ⋅z   - 155520⋅q ⋅z   - 658368⋅q ⋅z  + 1177092.0⋅q ⋅z  + 103
#
#          2  7               2  6               2  5                    2  4
# 40136.0⋅q ⋅z  + 23040173.0⋅q ⋅z  + 26181862.5⋅q ⋅z  + 16824775.640625⋅q ⋅z  +
#
#                 2  3                     2  2                     2
# 5987953.265625⋅q ⋅z  + 1020487.33007813⋅q ⋅z  + 49595.2119140625⋅q ⋅z + 314.69
#
#             2              3  5              3  4              3  3
# 4030761719⋅q  + 1024000⋅q⋅s ⋅z  + 3840000⋅q⋅s ⋅z  + 5760000⋅q⋅s ⋅z  + 4320000⋅
#
#    3  2              3               3             2    4              2    3
# q⋅s ⋅z  + 1620000⋅q⋅s ⋅z + 243000⋅q⋅s  + 460800⋅q⋅s ⋅t⋅z  + 1382400⋅q⋅s ⋅t⋅z
#
#              2    2             2                 2               2  8
# + 1555200⋅q⋅s ⋅t⋅z  + 777600⋅q⋅s ⋅t⋅z + 145800⋅q⋅s ⋅t + 153600⋅q⋅s ⋅z  + 46080
#
#      2  7              2  6               2  5                 2  4
# 0⋅q⋅s ⋅z  - 3628800⋅q⋅s ⋅z  - 16329600⋅q⋅s ⋅z  - 26535600.0⋅q⋅s ⋅z  - 21432600
#
#       2  3                2  2                2                    2
# .0⋅q⋅s ⋅z  - 8801075.0⋅q⋅s ⋅z  - 1555837.5⋅q⋅s ⋅z - 45232.03125⋅q⋅s  + 69120⋅q
#
#     2  3               2  2               2                2                7
# ⋅s⋅t ⋅z  + 155520⋅q⋅s⋅t ⋅z  + 116640⋅q⋅s⋅t ⋅z + 29160⋅q⋅s⋅t  + 46080⋅q⋅s⋅t⋅z
#
#                 6                  5                  4                    3
# + 103680⋅q⋅s⋅t⋅z  - 1166400⋅q⋅s⋅t⋅z  - 4024080⋅q⋅s⋅t⋅z  - 4942620.0⋅q⋅s⋅t⋅z  -
#
#                   2                                                    11
#  2722815.0⋅q⋅s⋅t⋅z  - 598211.25⋅q⋅s⋅t⋅z - 18092.8125⋅q⋅s⋅t + 7680⋅q⋅s⋅z   + 17
#
#          10               9                8                  7
# 280⋅q⋅s⋅z   - 401760⋅q⋅s⋅z  - 1344600⋅q⋅s⋅z  + 3951180.0⋅q⋅s⋅z  + 22886955.0⋅q
#
#     6                    5                      4                         3
# ⋅s⋅z  + 40435056.25⋅q⋅s⋅z  + 35128124.0625⋅q⋅s⋅z  + 15720076.0546875⋅q⋅s⋅z  +
#
#                       2
# 3190706.12304688⋅q⋅s⋅z  + 167310.607910156⋅q⋅s⋅z + 1117.88635253906⋅q⋅s + 3456
#
#     3  2           3             3           2  6           2  5            2
# ⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z + 1944⋅q⋅t  + 3456⋅q⋅t ⋅z  + 5184⋅q⋅t ⋅z  - 91368⋅q⋅t ⋅
#
#  4             2  3               2  2               2                   2
# z  - 233280⋅q⋅t ⋅z  - 195736.5⋅q⋅t ⋅z  - 57408.75⋅q⋅t ⋅z - 1809.28125⋅q⋅t  + 1
#
#          10             9              8               7                 6
# 152⋅q⋅t⋅z   + 1728⋅q⋅t⋅z  - 61560⋅q⋅t⋅z  - 155520⋅q⋅t⋅z  + 709317.0⋅q⋅t⋅z  + 2
#
#               5                     4                  3
# 901055.5⋅q⋅t⋅z  + 3889466.8125⋅q⋅t⋅z  + 2352118.5⋅q⋅t⋅z  + 593922.533203125⋅q⋅
#
#    2                                                          14          13
# t⋅z  + 33152.0185546875⋅q⋅t⋅z + 214.577270507813⋅q⋅t + 128⋅q⋅z   + 192⋅q⋅z   -
#
#           12            11               10                9
#  10296⋅q⋅z   - 25920⋅q⋅z   + 258187.5⋅q⋅z   + 973397.25⋅q⋅z  - 1222734.03125⋅q
#
#   8                 7                       6                       5
# ⋅z  - 10553368.5⋅q⋅z  - 20380602.3222656⋅q⋅z  - 19027331.0771484⋅q⋅z  - 924353
#
#               4                       3                       2
# 5.99182129⋅q⋅z  - 2117634.65332031⋅q⋅z  - 153760.023399353⋅q⋅z  - 1949.8587684
#
#                                        4  4           4  3            4  2
# 6313⋅q⋅z - 6.8399977684021⋅q + 320000⋅s ⋅z  + 960000⋅s ⋅z  + 1080000⋅s ⋅z  + 5
#
#        4             4           3    3           3    2           3
# 40000⋅s ⋅z + 101250⋅s  + 192000⋅s ⋅t⋅z  + 432000⋅s ⋅t⋅z  + 324000⋅s ⋅t⋅z + 810
#
#     3            3  7           3  6            3  5            3  4
# 00⋅s ⋅t + 64000⋅s ⋅z  + 144000⋅s ⋅z  - 1620000⋅s ⋅z  - 5589000⋅s ⋅z  - 6864750
#
#     3  3              3  2               3                  3          2  2  2
# .0⋅s ⋅z  - 3781687.5⋅s ⋅z  - 831515.625⋅s ⋅z - 25628.90625⋅s  + 43200⋅s ⋅t ⋅z
#
#           2  2            2  2          2    6          2    5           2
#  + 64800⋅s ⋅t ⋅z + 24300⋅s ⋅t  + 28800⋅s ⋅t⋅z  + 43200⋅s ⋅t⋅z  - 761400⋅s ⋅t⋅z
#
# 4            2    3              2    2              2                    2
#   - 1944000⋅s ⋅t⋅z  - 1631137.5⋅s ⋅t⋅z  - 478406.25⋅s ⋅t⋅z - 15377.34375⋅s ⋅t
#
#         2  10         2  9           2  8           2  7              2  6
# + 4800⋅s ⋅z   + 7200⋅s ⋅z  - 256500⋅s ⋅z  - 648000⋅s ⋅z  + 2955487.5⋅s ⋅z  + 1
#
#             2  5                   2  4               2  3
# 2087731.25⋅s ⋅z  + 16206011.71875⋅s ⋅z  + 9800493.75⋅s ⋅z  + 2477377.22167969⋅
#
#  2  2                     2                       2           3             3
# s ⋅z  + 140933.410644531⋅s ⋅z + 988.993835449219⋅s  + 4320⋅s⋅t ⋅z + 3240⋅s⋅t
#
#           2  5           2  4             2  3             2  2
# + 4320⋅s⋅t ⋅z  + 3240⋅s⋅t ⋅z  - 116640⋅s⋅t ⋅z  - 204120⋅s⋅t ⋅z  - 91580.625⋅s⋅
#
#  2                   2             9             8              7
# t ⋅z - 3075.46875⋅s⋅t  + 1440⋅s⋅t⋅z  + 1080⋅s⋅t⋅z  - 77760⋅s⋅t⋅z  - 136080⋅s⋅t
#
#   6                  5                     4                   3
# ⋅z  + 988706.25⋅s⋅t⋅z  + 2884789.6875⋅s⋅t⋅z  + 2698211.25⋅s⋅t⋅z  + 916489.6875
#
#       2                                                          13          1
# ⋅s⋅t⋅z  + 55845.9008789063⋅s⋅t⋅z + 380.597534179688⋅s⋅t + 160⋅s⋅z   + 120⋅s⋅z
#
# 2            11            10                 9                   8
#   - 12960⋅s⋅z   - 22680⋅s⋅z   + 339744.375⋅s⋅z  + 961938.28125⋅s⋅z  - 2249876.
#
#       7                    6                      5                       4
# 25⋅s⋅z  - 11504303.4375⋅s⋅z  - 16847255.324707⋅s⋅z  - 11148447.3529053⋅s⋅z  -
#
#                     3                       2
# 3196723.73291016⋅s⋅z  - 256925.516967773⋅s⋅z  - 3440.93058586121⋅s⋅z - 12.6606
#
#                    4        3  4         3  2         3                3
# 774330139⋅s + 162⋅t  + 216⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z - 205.03125⋅t  + 108
#
#   2  8         2  6         2  5                2  4           2  3
# ⋅t ⋅z  - 5832⋅t ⋅z  - 5832⋅t ⋅z  + 78526.96875⋅t ⋅z  + 157464⋅t ⋅z  + 84267.84
#
#      2  2               2                       2         12           10
# 375⋅t ⋅z  + 5535.84375⋅t ⋅z + 36.5597534179688⋅t  + 24⋅t⋅z   - 1944⋅t⋅z   - 19
#
#       9                  8             7                  6
# 44⋅t⋅z  + 52419.65625⋅t⋅z  + 104976⋅t⋅z  - 416213.4375⋅t⋅z  - 1413485.4375⋅t⋅z
#
# 5                       4                  3                       2
#   - 1466974.22058105⋅t⋅z  - 572037.1875⋅t⋅z  - 50480.6693115234⋅t⋅z  - 658.075
#
#                                         16        14        13               1
# 561523438⋅t⋅z + 3.66708326339722⋅t + 2⋅z   - 216⋅z   - 216⋅z   + 8740.40625⋅z
#
# 2          11                 10                 9                     8
#   + 17496⋅z   - 148100.90625⋅z   - 471776.90625⋅z  + 573886.530944824⋅z  + 406
#
#            7                     6                     5                     4
# 0848.9375⋅z  + 6509932.89147949⋅z  + 4699711.98522949⋅z  + 1514245.90613794⋅z
#
#                      3                     2
#  + 155390.461303711⋅z  + 2982.33627748489⋅z  + 20.996250629425⋅z + 0.050589986
#
#
# 6111576

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sympy import*
init_printing(use_unicode=True)
import fractions
import math

A,P,Q,R,T,r,q,s,t,M = symbols ("A P Q R T r q s t M")

# %%
qst_tuple = ( {q:1, s:1, t:1}, {q:1, s:-1, t:1}, {q:1, s:2, t:3}, {q:1, s:-2, t:3}, {q:2, s:1, t:3}, {q:2, s:-1, t:3} ) # set of q,s,t
qst_tuple
# Out:
# ({q: 1, s: 1, t: 1}, {q: 1, s: -1, t: 1}, {q: 1, s: 2, t: 3}, {q: 1, s: -2, t:
#  3}, {q: 2, s: 1, t: 3}, {q: 2, s: -1, t: 3})

# %%
A = 1 - (2*M/r) + (q*M**2/r**2) + (s*M**3/r**3) + (t*M**4/r**4) # g_{tt}

Eq(A,0)
# Out:
#  4      3      2
# M ⋅t   M ⋅s   M ⋅q   2⋅M
# ──── + ──── + ──── - ─── + 1 = 0
#   4      3      2     r
#  r      r      r

# %%
photon_sphere_radius = ( (3/4) + sqrt( ( 2*sqrt( 25 - 192*t ) - 1 ) / (16) ) )*M

Eq(photon_sphere_radius,0) #Just to show the expression, it's not an equation
# Out:
#   ⎛     _____________________       ⎞
#   ⎜    ╱   ____________             ⎟
#   ⎜   ╱  ╲╱ 25 - 192⋅t    1         ⎟
# M⋅⎜  ╱   ────────────── - ──  + 0.75⎟ = 0
#   ⎝╲╱          8          16        ⎠

# %%
A_Photon_Sphere = expand(A.subs(r,(photon_sphere_radius))) # g_{tt} at the photon sphere
simplify(A_Photon_Sphere)
Eq(A_Photon_Sphere,0)
# Out:
#                           q
# ───────────────────────────────────────────────────── + ──────────────────────
#                           _____________________                             __
#   ____________           ╱   ____________                                  ╱
# ╲╱ 25 - 192⋅t           ╱  ╲╱ 25 - 192⋅t    1             ____________    ╱  ╲
# ────────────── + 1.5⋅  ╱   ────────────── - ──  + 0.5   ╲╱ 25 - 192⋅t ⋅  ╱   ─
#       8              ╲╱          8          16                         ╲╱
#                                                         ──────────────────────
#                                                                             8
#
#                                  s
# ──────────────────────────────────────────────────────────────────────────────
# ___________________
#  ____________
# ╱ 25 - 192⋅t    1                                         ____________________
# ───────────── - ──                                       ╱   ____________
#      8          16              ____________            ╱  ╲╱ 25 - 192⋅t    1
# ─────────────────── + 0.28125⋅╲╱ 25 - 192⋅t  + 1.625⋅  ╱   ────────────── - ──
#                                                      ╲╱          8          16
#
#                                                                         t
# ─────────── + ────────────────────────────────────────────────────────────────
#                                                _____________________
#                                               ╱   ____________
# _                            ____________    ╱  ╲╱ 25 - 192⋅t    1
#               -3⋅t + 0.375⋅╲╱ 25 - 192⋅t ⋅  ╱   ────────────── - ──  + 0.40625
#                                           ╲╱          8          16
#   + 0.28125
#
#
#                                                                              2
# ────────────────────────────────────────────────────── + 1 - ─────────────────
#                            _____________________                  ____________
#                           ╱   ____________                       ╱   _________
#    ____________          ╱  ╲╱ 25 - 192⋅t    1                  ╱  ╲╱ 25 - 192
# ⋅╲╱ 25 - 192⋅t  + 1.5⋅  ╱   ────────────── - ──  + 0.5         ╱   ───────────
#                       ╲╱          8          16              ╲╱          8
#
#
#
#
# ──────────────── = 0
# _________
# ___
# ⋅t    1
# ─── - ──  + 0.75
#       16

# %%
A_Photon_Sphere_Substituted = A_Photon_Sphere.subs({q:1, s:1, t:1}) # g_{tt} at photn sphere for (q,s,t) = (1,1,1)

Eq(A_Photon_Sphere_Substituted,0)
# Out:
#                       1
# 1 + ────────────────────────────────────── + ─────────────────────────────────
#                   _______________                                 ____________
#                  ╱   1    √167⋅ⅈ    √167⋅ⅈ                       ╱   1    √167
#     0.5 + 1.5⋅  ╱  - ── + ──────  + ──────             √167⋅ⅈ⋅  ╱  - ── + ────
#               ╲╱     16     8         8                       ╲╱     16     8
#                                              0.28125 + ───────────────────────
#                                                                    8
#
#        1
# ──────────────────────────────────────────────── + ───────────────────────────
# ___                                                               ____________
# ⋅ⅈ                                                               ╱   1    √167
# ──              _______________                    -2.5 + 1.5⋅  ╱  - ── + ────
#                ╱   1    √167⋅ⅈ                                ╲╱     16     8
# ─── + 1.625⋅  ╱  - ── + ──────  + 0.28125⋅√167⋅ⅈ
#             ╲╱     16     8
#
#              1                                                        2
# ─────────────────────────────────────────────────────── - ────────────────────
# ___                    _______________                               _________
# ⋅ⅈ                    ╱   1    √167⋅ⅈ                               ╱   1    √
# ──  + 0.375⋅√167⋅ⅈ⋅  ╱  - ── + ──────  + 0.40625⋅√167⋅ⅈ   0.75 +   ╱  - ── + ─
#                    ╲╱     16     8                               ╲╱     16
#
#
#
#
# ────── = 0
# ______
# 167⋅ⅈ
# ─────
#  8

# %%
sol = solve(A_Photon_Sphere_Substituted,r)
sol
# Out:
# []

# %%
fractions.Fraction(6.75)
# Out:
# Fraction(27, 4)

# %%
fractions.Fraction(3.75)
# Out:
# Fraction(15, 4)

# %%
fractions.Fraction(1.8984375)
# Out:
# Fraction(243, 128)

# %%
fractions.Fraction(6.75)
# Out:
# Fraction(27, 4)

# %%
fractions.Fraction(0.1875)
# Out:
# Fraction(3, 16)
